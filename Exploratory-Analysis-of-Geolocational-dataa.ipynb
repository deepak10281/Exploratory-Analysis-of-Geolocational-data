# %%
import pandas as pd
data = pd.read_csv(r"C:\Users\Admin\Documents\Deepak Documents\PROJECTS\MAJOR PROJECT\food_coded.csv", low_memory=False)

# %%
data
# Out:
#        GPA  Gender  breakfast  calories_chicken  calories_day  calories_scone  \
# 0      2.4       2          1               430           NaN           315.0
# 1    3.654       1          1               610           3.0           420.0
# 2      3.3       1          1               720           4.0           420.0
# 3      3.2       1          1               430           3.0           420.0
# 4      3.5       1          1               720           2.0           420.0
# ..     ...     ...        ...               ...           ...             ...
# 120    3.5       1          1               610           4.0           420.0
# 121      3       1          1               265           2.0           315.0
# 122  3.882       1          1               720           NaN           420.0
# 123      3       2          1               720           4.0           420.0
# 124    3.9       1          1               430           NaN           315.0
#
#      coffee                             comfort_food  \
# 0         1                                     none
# 1         2              chocolate, chips, ice cream
# 2         2          frozen yogurt, pizza, fast food
# 3         2         Pizza, Mac and cheese, ice cream
# 4         2             Ice cream, chocolate, chips
# ..      ...                                      ...
# 120       2  wine. mac and cheese, pizza, ice cream
# 121       2               Pizza / Wings / Cheesecake
# 122       1               rice, potato, seaweed soup
# 123       1             Mac n Cheese, Lasagna, Pizza
# 124       2             Chocolates, pizza, and Ritz.
#
#                               comfort_food_reasons  \
# 0                            we dont have comfort
# 1                             Stress, bored, anger
# 2                                  stress, sadness
# 3                                          Boredom
# 4                       Stress, boredom, cravings
# ..                                             ...
# 120                           boredom and sadness
# 121                Loneliness / Homesick / Sadness
# 122                                        sadness
# 123  happiness, they are some of my favorite foods
# 124               hormones, Premenstrual syndrome.
#
#      comfort_food_reasons_coded  ...  Column16316  Column16317  Column16318  \
# 0                           9.0  ...          NaN          NaN          NaN
# 1                           1.0  ...          NaN          NaN          NaN
# 2                           1.0  ...          NaN          NaN          NaN
# 3                           2.0  ...          NaN          NaN          NaN
# 4                           1.0  ...          NaN          NaN          NaN
# ..                          ...  ...          ...          ...          ...
# 120                         NaN  ...          NaN          NaN          NaN
# 121                         NaN  ...          NaN          NaN          NaN
# 122                         NaN  ...          NaN          NaN          NaN
# 123                         NaN  ...          NaN          NaN          NaN
# 124                         NaN  ...          NaN          NaN          NaN
#
#     Column16319  Column16320  Column16321 Column16322  Column16323  \
# 0           NaN          NaN          NaN         NaN          NaN
# 1           NaN          NaN          NaN         NaN          NaN
# 2           NaN          NaN          NaN         NaN          NaN
# 3           NaN          NaN          NaN         NaN          NaN
# 4           NaN          NaN          NaN         NaN          NaN
# ..          ...          ...          ...         ...          ...
# 120         NaN          NaN          NaN         NaN          NaN
# 121         NaN          NaN          NaN         NaN          NaN
# 122         NaN          NaN          NaN         NaN          NaN
# 123         NaN          NaN          NaN         NaN          NaN
# 124         NaN          NaN          NaN         NaN          NaN
#
#      Column16324  Column16325
# 0            NaN          NaN
# 1            NaN          NaN
# 2            NaN          NaN
# 3            NaN          NaN
# 4            NaN          NaN
# ..           ...          ...
# 120          NaN          NaN
# 121          NaN          NaN
# 122          NaN          NaN
# 123          NaN          NaN
# 124          NaN          NaN
#
# [125 rows x 16384 columns]

# %%
data.columns
# Out:
# Index(['GPA', 'Gender', 'breakfast', 'calories_chicken', 'calories_day',
#        'calories_scone', 'coffee', 'comfort_food', 'comfort_food_reasons',
#        'comfort_food_reasons_coded',
#        ...
#        'Column16316', 'Column16317', 'Column16318', 'Column16319',
#        'Column16320', 'Column16321', 'Column16322', 'Column16323',
#        'Column16324', 'Column16325'],
#       dtype='object', length=16384)

# %%
column=['cook','eating_out','employment','ethnic_food', 'exercise','fruit_day','income','on_off_campus','pay_meal_out','sports','veggies_day']

# %%
d=data[column]

# %%
d
# Out:
#      cook  eating_out  employment  ethnic_food  exercise  fruit_day  income  \
# 0     2.0           3         3.0            1       1.0          5     5.0
# 1     3.0           2         2.0            4       1.0          4     4.0
# 2     1.0           2         3.0            5       2.0          5     6.0
# 3     2.0           2         3.0            5       3.0          4     6.0
# 4     1.0           2         2.0            4       1.0          4     6.0
# ..    ...         ...         ...          ...       ...        ...     ...
# 120   3.0           2         1.0            4       2.0          5     4.0
# 121   3.0           4         3.0            3       2.0          4     2.0
# 122   3.0           3         3.0            5       2.0          4     2.0
# 123   3.0           5         2.0            2       1.0          5     4.0
# 124   NaN           1         2.0            3       2.0          3     5.0
#
#      on_off_campus  pay_meal_out  sports  veggies_day
# 0              1.0             2     1.0            5
# 1              1.0             4     1.0            4
# 2              2.0             3     2.0            5
# 3              1.0             2     2.0            3
# 4              1.0             4     1.0            4
# ..             ...           ...     ...          ...
# 120            3.0             4     1.0            5
# 121            1.0             4     NaN            5
# 122            1.0             4     2.0            4
# 123            1.0             3     2.0            3
# 124            1.0             3     2.0            4
#
# [125 rows x 11 columns]

# %%
import seaborn as sns
sns.pairplot(d)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
ax=d.boxplot(figsize=(16,6))
ax.set_xticklabels(ax.get_xticklabels(),rotation=30)
# Out:
# [Text(1, 0, 'cook'),
#  Text(2, 0, 'eating_out'),
#  Text(3, 0, 'employment'),
#  Text(4, 0, 'ethnic_food'),
#  Text(5, 0, 'exercise'),
#  Text(6, 0, 'fruit_day'),
#  Text(7, 0, 'income'),
#  Text(8, 0, 'on_off_campus'),
#  Text(9, 0, 'pay_meal_out'),
#  Text(10, 0, 'sports'),
#  Text(11, 0, 'veggies_day')]

# %%
d.shape
# Out:
# (125, 11)

# %%
s=d.dropna()

# %%
## for data
import numpy as np
import pandas as pd
## for plotting
import matplotlib.pyplot as plt
import seaborn as sns
## for geospatial
import folium
import geopy
## for machine learning
from sklearn import preprocessing, cluster
import scipy
## for deep learning
#import minisom

# %%
f=['cook','income']
X = s[f]
max_k = 10
## iterations
distortions = []
for i in range(1, max_k+1):
    if len(X) >= i:
       model = cluster.KMeans(n_clusters=i, init='k-means++', max_iter=300, n_init=10, random_state=0)
       model.fit(X)
       distortions.append(model.inertia_)
## best k: the lowest derivative
k = [i*100 for i in np.diff(distortions,2)].index(min([i*100 for i
     in np.diff(distortions,2)]))
## plot
fig, ax = plt.subplots()
ax.plot(range(1, len(distortions)+1), distortions)
ax.axvline(k, ls='--', color="red", label="k = "+str(k))
ax.set(title='The Elbow Method', xlabel='Number of clusters',
       ylabel="Distortion")
ax.legend()
ax.grid(True)
plt.show()
# Out:
# C:\Users\Admin\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1419: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\Admin\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1419: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\Admin\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1419: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\Admin\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1419: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\Admin\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1419: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\Admin\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1419: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\Admin\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1419: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\Admin\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1419: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\Admin\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1419: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\Admin\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1419: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %%
import pandas as pd
import folium
from geopy.geocoders import Nominatim
import requests
CLIENT_ID = "KTCJJ2YZ2143QHEZ2JAQS4FJIO5DLSDO0YN4YBXPMI5NKTEF" # your Foursquare ID
CLIENT_SECRET = "KNG2LO22BPLHN1E3OAHWLYQ5PQBN14XYZMEMAS0CPJEJKOTR" # your Foursquare Secret
VERSION = '20200316'
LIMIT = 10000

# Instead of: from pandas.io.json import json_normalize
# Use:
from pandas import json_normalize # Import json_normalize directly from pandas

# %%
url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
    CLIENT_ID,
    CLIENT_SECRET,
    VERSION,
    17.448372, 78.526957,
    30000,
    LIMIT)

# %%
results = requests.get(url).json()

# %%
results
# Out:
# {'meta': {'code': 200, 'requestId': '694410c3b8bbca63a0921909'},
#  'response': {'queryRefinements': {'target': {'type': 'path',
#     'url': '/venue/explore',
#     'params': {'ll': '17.448372,78.526957', 'radius': '30000'}},
#    'refinements': [{'query': 'Food'},
#     {'query': 'Nightlife'},
#     {'query': 'Coffee'},
#     {'query': 'Shops'},
#     {'query': 'Arts'},
#     {'query': 'Outdoors'}]},
#   'suggestedFilters': {'header': 'Tap to show:',
#    'filters': [{'name': 'Open now', 'key': 'openNow'}]},
#   'headerLocation': 'Hyderabad',
#   'headerFullLocation': 'Hyderabad',
#   'headerLocationGranularity': 'city',
#   'totalResults': 143,
#   'suggestedBounds': {'ne': {'lat': 17.71837227000027,
#     'lng': 78.80945141641452},
#    'sw': {'lat': 17.17837172999973, 'lng': 78.24446258358547}},
#   'groups': [{'type': 'Recommended Places',
#     'name': 'recommended',
#     'items': [{'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bac7d4df964a5205df73ae3',
#        'name': '10 Downing Street',
#        'location': {'address': 'Ground Floor, Lifestyle Building, Greenlands',
#         'crossStreet': 'Begumpet Rd',
#         'lat': 17.43586817493973,
#         'lng': 78.45744348829194,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 17.43586817493973,
#           'lng': 78.45744348829194}],
#         'distance': 7512,
#         'postalCode': '500016',
#         'cc': 'IN',
#         'city': 'Hyderabad',
#         'state': 'Telangana',
#         'country': 'India',
#         'formattedAddress': ['Ground Floor, Lifestyle Building, Greenlands (Begumpet Rd)',
#          'Hyderabad 500016',
#          'Telangana',
#          'India']},
#        'categories': [{'id': '4bf58dd8d48988d11b941735',
#          'name': 'Pub',
#          'pluralName': 'Pubs',
#          'shortName': 'Pub',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#           'suffix': '.png'},
#          'categoryCode': 13018,
#          'mapIcon': 'fsq-bar',
#          'mapTextColor': '#ff5c00',
#          'mapDarkTextColor': '#ffa66e',
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'createdAt': 1269595469},
#       'photo': {'id': '529388ce498ec78f1904dd61',
#        'createdAt': 1385400526,
#        'prefix': 'https://fastly.4sqi.net/img/general/',
#        'suffix': '/32609040_X0yOzEI5oGptuXM0aoHecUKM9ssqdHLfHNHF_QWQj4U.jpg',
#        'width': 970,
#        'height': 650,
#        'visibility': 'public'},
#       'referralId': 'e-0-4bac7d4df964a5205df73ae3-0'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4e1b27cbd22ddd4af9ea6366',
#        'name': 'ITC Kakatiya',
#        'location': {'address': '6 -3 -1187, Begumpet',
#         'crossStreet': 'Begumpet',
#         'lat': 17.432514031982514,
#         'lng': 78.45735255628313,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 17.432514031982514,
#           'lng': 78.45735255628313}],
#         'distance': 7599,
#         'postalCode': '500016',
#         'cc': 'IN',
#         'city': 'Hyderabad',
#         'state': 'Telangana',
#         'country': 'India',
#         'formattedAddress': ['6 -3 -1187, Begumpet (Begumpet)',
#          'Hyderabad 500016',
#          'Telangana',
#          'India']},
#        'categories': [{'id': '4bf58dd8d48988d1fa931735',
#          'name': 'Hotel',
#          'pluralName': 'Hotels',
#          'shortName': 'Hotel',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#           'suffix': '.png'},
#          'categoryCode': 19014,
#          'mapIcon': 'fsq-lodging',
#          'mapTextColor': '#4285f4',
#          'mapDarkTextColor': '#91bafc',
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'createdAt': 1310402507},
#       'photo': {'id': '5039d2cfe4b08256fb6f9235',
#        'createdAt': 1345966799,
#        'prefix': 'https://fastly.4sqi.net/img/general/',
#        'suffix': '/jIxkFJ4NX8zo6es-KAJUljhtdjADHd8Et-kT5Q8t_oQ.jpg',
#        'width': 612,
#        'height': 612,
#        'visibility': 'public'},
#       'referralId': 'e-0-4e1b27cbd22ddd4af9ea6366-1'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c68e4238d22c928e6f2b545',
#        'name': 'Secunderabad Club',
#        'location': {'address': 'Picket',
#         'lat': 17.452548018373523,
#         'lng': 78.49740039245621,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 17.452548018373523,
#           'lng': 78.49740039245621}],
#         'distance': 3173,
#         'postalCode': '500026',
#         'cc': 'IN',
#         'city': 'Secunderabad',
#         'state': 'Telangana',
#         'country': 'India',
#         'formattedAddress': ['Picket',
#          'Secunderabad 500026',
#          'Telangana',
#          'India']},
#        'categories': [{'id': '4d4b7104d754a06370d81259',
#          'name': 'Arts and Entertainment',
#          'pluralName': 'Arts and Entertainment',
#          'shortName': 'Arts & Entertainment',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/default_',
#           'suffix': '.png'},
#          'categoryCode': 10000,
#          'mapIcon': 'fsq-arts-entertainment',
#          'mapTextColor': '#9162fe',
#          'mapDarkTextColor': '#d3bfff',
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'createdAt': 1281942563},
#       'photo': {'id': '61d854c052dc4a469d721467',
#        'createdAt': 1641567424,
#        'prefix': 'https://fastly.4sqi.net/img/general/',
#        'suffix': '/36980127_TRsV_zibmCz5rS1m3cHu5qywc8p1w3d19zO-fHsuG8Q.jpg',
#        'width': 1920,
#        'height': 1440,
#        'visibility': 'public'},
#       'referralId': 'e-0-4c68e4238d22c928e6f2b545-2'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c1f7229b306c928046b68b7',
#        'name': 'Fifth Avenue Bakers',
#        'location': {'address': 'Sainikpuri',
#         'lat': 17.487673346331192,
#         'lng': 78.54279287522861,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 17.487673346331192,
#           'lng': 78.54279287522861}],
#         'distance': 4687,
#         'cc': 'IN',
#         'state': 'Andhra Pradesh',
#         'country': 'India',
#         'formattedAddress': ['Sainikpuri', 'Andhra Pradesh', 'India']},
#        'categories': [{'id': '4bf58dd8d48988d16a941735',
#          'name': 'Bakery',
#          'pluralName': 'Bakeries',
#          'shortName': 'Bakery',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#           'suffix': '.png'},
#          'categoryCode': 13002,
#          'mapIcon': 'fsq-bakery',
#          'mapTextColor': '#ff5c00',
#          'mapDarkTextColor': '#ffa66e',
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'createdAt': 1277129257},
#       'photo': {'id': '5410601c11d2a80070a4d902',
#        'createdAt': 1410359324,
#        'prefix': 'https://fastly.4sqi.net/img/general/',
#        'suffix': '/58807053_Az0izB4nYIHej7aiec35wqyHdb71ssAD5yHmESElVBk.jpg',
#        'width': 540,
#        'height': 960,
#        'visibility': 'public'},
#       'referralId': 'e-0-4c1f7229b306c928046b68b7-3'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4df9c65c62e1e9a24367f9e5',
#        'name': 'King & Cardinal',
#        'location': {'address': 'Himayatnagar',
#         'crossStreet': 'Narayanguda-himayat Nagar X Roads',
#         'lat': 17.40067830505242,
#         'lng': 78.48857489055783,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 17.40067830505242,
#           'lng': 78.48857489055783}],
#         'distance': 6693,
#         'postalCode': '500029',
#         'cc': 'IN',
#         'city': 'Hyderabad',
#         'state': 'Telangana',
#         'country': 'India',
#         'formattedAddress': ['Himayatnagar (Narayanguda-himayat Nagar X Roads)',
#          'Hyderabad 500029',
#          'Telangana',
#          'India']},
#        'categories': [{'id': '4bf58dd8d48988d16c941735',
#          'name': 'Burger Joint',
#          'pluralName': 'Burger Joints',
#          'shortName': 'Burgers',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/burger_',
#           'suffix': '.png'},
#          'categoryCode': 13031,
#          'mapIcon': 'fsq-dining',
#          'mapTextColor': '#ff5c00',
#          'mapDarkTextColor': '#ffa66e',
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'createdAt': 1308214876},
#       'photo': {'id': '511f9153e4b0841ee067e14a',
#        'createdAt': 1361023315,
#        'prefix': 'https://fastly.4sqi.net/img/general/',
#        'suffix': '/40470832_8JS8r4wwSPHFEIT1zrQnB9cEBP7CykzzHPhtYOaWZCo.jpg',
#        'width': 960,
#        'height': 540,
#        'visibility': 'public'},
#       'referralId': 'e-0-4df9c65c62e1e9a24367f9e5-4'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4e5b27778877c8a76dfc0f0c',
#        'name': 'Vivanta by Taj',
#        'location': {'address': 'Vivanta By Taj - Begumpet, Hyderabad',
#         'crossStreet': '1-10-147 & 148, Mayuri Marg',
#         'lat': 17.44349840742226,
#         'lng': 78.4605560466047,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 17.44349840742226,
#           'lng': 78.4605560466047}],
#         'distance': 7072,
#         'postalCode': '500016',
#         'cc': 'IN',
#         'city': 'Begumpet',
#         'state': 'Telangana',
#         'country': 'India',
#         'formattedAddress': ['Vivanta By Taj - Begumpet, Hyderabad (1-10-147 & 148, Mayuri Marg)',
#          'Begumpet 500016',
#          'Telangana',
#          'India']},
#        'categories': [{'id': '4bf58dd8d48988d1fa931735',
#          'name': 'Hotel',
#          'pluralName': 'Hotels',
#          'shortName': 'Hotel',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#           'suffix': '.png'},
#          'categoryCode': 19014,
#          'mapIcon': 'fsq-lodging',
#          'mapTextColor': '#4285f4',
#          'mapDarkTextColor': '#91bafc',
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'createdAt': 1314596727},
#       'photo': {'id': '4f478b4de4b0dd9bf32f6fd9',
#        'createdAt': 1330088781,
#        'prefix': 'https://fastly.4sqi.net/img/general/',
#        'suffix': '/Tij1vvyb4tpU5ugxnu7AitAHPuM5fZ3lsvQT6GbLnho.jpg',
#        'width': 2592,
#        'height': 1944,
#        'visibility': 'public'},
#       'referralId': 'e-0-4e5b27778877c8a76dfc0f0c-5'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4e089859a809495e619fa4d7',
#        'name': 'Necklace Road',
#        'location': {'address': 'Tank Bund',
#         'lat': 17.419383551461067,
#         'lng': 78.46530662997712,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 17.419383551461067,
#           'lng': 78.46530662997712}],
#         'distance': 7299,
#         'cc': 'IN',
#         'city': 'Hyderabad',
#         'state': 'Telangana',
#         'country': 'India',
#         'formattedAddress': ['Tank Bund', 'Hyderabad', 'Telangana', 'India']},
#        'categories': [{'id': '4bf58dd8d48988d165941735',
#          'name': 'Scenic Lookout',
#          'pluralName': 'Scenic Lookouts',
#          'shortName': 'Scenic Lookout',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/sceniclookout_',
#           'suffix': '.png'},
#          'categoryCode': 16046,
#          'mapIcon': 'fsq-landmarks-outdoors',
#          'mapTextColor': '#39b88b',
#          'mapDarkTextColor': '#64d0aa',
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'createdAt': 1309186137},
#       'photo': {'id': '50fd40b8e4b0ef4ba433fbff',
#        'createdAt': 1358774456,
#        'prefix': 'https://fastly.4sqi.net/img/general/',
#        'suffix': '/16464317_gDv_ku3i2Xls84OFOQc1BzyAxtwd80eV39RU0XsIbeU.jpg',
#        'width': 612,
#        'height': 612,
#        'visibility': 'public'},
#       'referralId': 'e-0-4e089859a809495e619fa4d7-6'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bdae2dac4e5952110c36a08',
#        'name': 'Lamakaan',
#        'location': {'address': 'Next to C Bay, Banjara Hills',
#         'crossStreet': 'Rd No 1',
#         'lat': 17.42101717782916,
#         'lng': 78.44747414471229,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 17.42101717782916,
#           'lng': 78.44747414471229}],
#         'distance': 8973,
#         'cc': 'IN',
#         'city': 'Hyderabad',
#         'state': 'Telangana',
#         'country': 'India',
#         'formattedAddress': ['Next to C Bay, Banjara Hills (Rd No 1)',
#          'Hyderabad',
#          'Telangana',
#          'India']},
#        'categories': [{'id': '4bf58dd8d48988d1f2931735',
#          'name': 'Performing Arts Venue',
#          'pluralName': 'Performing Arts Venues',
#          'shortName': 'Performing Arts',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/performingarts_',
#           'suffix': '.png'},
#          'categoryCode': 10035,
#          'mapIcon': 'fsq-arts-entertainment',
#          'mapTextColor': '#9162fe',
#          'mapDarkTextColor': '#d3bfff',
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'createdAt': 1272636122},
#       'photo': {'id': '5be1a1eb7dc9e1002cd93305',
#        'createdAt': 1541513707,
#        'prefix': 'https://fastly.4sqi.net/img/general/',
#        'suffix': '/38283723_8zdTT59Symwupbh-rVkjMVHJ84NUX2rSC9h2wADimKk.jpg',
#        'width': 1068,
#        'height': 1900,
#        'visibility': 'public'},
#       'referralId': 'e-0-4bdae2dac4e5952110c36a08-7'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4f66024de4b0777dfdc91dde',
#        'name': 'Cream Stone Concepts',
#        'location': {'address': 'Himayathnagar',
#         'lat': 17.404283602919396,
#         'lng': 78.48145782683908,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 17.404283602919396,
#           'lng': 78.48145782683908}],
#         'distance': 6887,
#         'postalCode': '500029',
#         'cc': 'IN',
#         'city': 'Hyderabad',
#         'state': 'Telangana',
#         'country': 'India',
#         'formattedAddress': ['Himayathnagar',
#          'Hyderabad 500029',
#          'Telangana',
#          'India']},
#        'categories': [{'id': '4bf58dd8d48988d1c9941735',
#          'name': 'Ice Cream Parlor',
#          'pluralName': 'Ice Cream Parlors',
#          'shortName': 'Ice Cream',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/icecream_',
#           'suffix': '.png'},
#          'categoryCode': 13046,
#          'mapIcon': 'fsq-dessert',
#          'mapTextColor': '#ff5c00',
#          'mapDarkTextColor': '#ffa66e',
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'createdAt': 1332085325},
#       'photo': {'id': '4f6605a2e4b036e3e9672a14',
#        'createdAt': 1332086178,
#        'prefix': 'https://fastly.4sqi.net/img/general/',
#        'suffix': '/vfHZv15Hg9ecM7vm2vAoWsAH0EF3Wp56j0aWvfxLqtg.jpg',
#        'width': 540,
#        'height': 720,
#        'visibility': 'public'},
#       'referralId': 'e-0-4f66024de4b0777dfdc91dde-8'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4f93cb30e4b03828fe09326a',
#        'name': 'Park Hyatt Hyderabad',
#        'location': {'address': 'Road No. 2 Banjara Hills',
#         'lat': 17.424764452273635,
#         'lng': 78.42960023866024,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 17.424764452273635,
#           'lng': 78.42960023866024}],
#         'distance': 10668,
#         'postalCode': '500034',
#         'cc': 'IN',
#         'city': 'Hyderabad',
#         'state': 'TG',
#         'country': 'India',
#         'formattedAddress': ['Road No. 2 Banjara Hills',
#          'Hyderabad 500034',
#          'TG',
#          'India']},
#        'categories': [{'id': '4bf58dd8d48988d1fa931735',
#          'name': 'Hotel',
#          'pluralName': 'Hotels',
#          'shortName': 'Hotel',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#           'suffix': '.png'},
#          'categoryCode': 19014,
#          'mapIcon': 'fsq-lodging',
#          'mapTextColor': '#4285f4',
#          'mapDarkTextColor': '#91bafc',
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'createdAt': 1335085872},
#       'photo': {'id': '6794bf652ac3723a412f363e',
#        'createdAt': 1737801573,
#        'prefix': 'https://fastly.4sqi.net/img/general/',
#        'suffix': '/1401079970_2KcrKJARh131Yk50JWn9O9sYXbN3DswNRg1JppHH_LA.jpg',
#        'width': 1080,
#        'height': 1920,
#        'visibility': 'public'},
#       'referralId': 'e-0-4f93cb30e4b03828fe09326a-9'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ea3fd3e490102dac340567a',
#        'name': 'The Coffee Cup',
#        'location': {'address': 'HP Petrol Bunk, Kushaiguda, Secunderabad, Andhra Pradesh',
#         'lat': 17.48318023870212,
#         'lng': 78.55210435802412,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 17.48318023870212,
#           'lng': 78.55210435802412}],
#         'distance': 4705,
#         'cc': 'IN',
#         'city': 'Secunderabad',
#         'state': 'Telangana',
#         'country': 'India',
#         'formattedAddress': ['HP Petrol Bunk, Kushaiguda, Secunderabad, Andhra Pradesh',
#          'Secunderabad',
#          'Telangana',
#          'India']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'categoryCode': 13034,
#          'mapIcon': 'fsq-coffee',
#          'mapTextColor': '#ff5c00',
#          'mapDarkTextColor': '#ffa66e',
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'createdAt': 1319370046},
#       'photo': {'id': '51531af8e4b050673d542813',
#        'createdAt': 1364400888,
#        'prefix': 'https://fastly.4sqi.net/img/general/',
#        'suffix': '/51614519_A1N0in1WwutNh_9wJkjrnb5RO7wyr3CuaHeiRTHMQ2A.jpg',
#        'width': 3552,
#        'height': 2000,
#        'visibility': 'public'},
#       'referralId': 'e-0-4ea3fd3e490102dac340567a-10'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c543cc0728920a13abe6a82',
#        'name': 'Kebabs & Kurries',
#        'location': {'address': 'Greenlands Flyover, Greenlands, Punjagutta',
#         'lat': 17.432374144194686,
#         'lng': 78.4575851947717,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 17.432374144194686,
#           'lng': 78.4575851947717}],
#         'distance': 7579,
#         'cc': 'IN',
#         'city': 'Hyderabad',
#         'state': 'Telangana',
#         'country': 'India',
#         'formattedAddress': ['Greenlands Flyover, Greenlands, Punjagutta',
#          'Hyderabad',
#          'Telangana',
#          'India']},
#        'categories': [{'id': '4bf58dd8d48988d10f941735',
#          'name': 'Indian Restaurant',
#          'pluralName': 'Indian Restaurants',
#          'shortName': 'Indian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#           'suffix': '.png'},
#          'categoryCode': 13199,
#          'mapIcon': 'fsq-dining',
#          'mapTextColor': '#ff5c00',
#          'mapDarkTextColor': '#ffa66e',
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'createdAt': 1280588992},
#       'photo': {'id': '649304fbde2ad94f0c44868e',
#        'createdAt': 1687356667,
#        'prefix': 'https://fastly.4sqi.net/img/general/',
#        'suffix': '/47373310_iTBBeHORRw37ezsiAKuyOcNfacTP8co-ng9VrMUnWBk.jpg',
#        'width': 1440,
#        'height': 1920,
#        'visibility': 'public'},
#       'referralId': 'e-0-4c543cc0728920a13abe6a82-11'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5050c114e4b0694f643d178e',
#        'name': 'Mekong',
#        'location': {'address': 'Leelanagar',
#         'crossStreet': 'Begumpet',
#         'lat': 17.437151274600346,
#         'lng': 78.45430121130967,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 17.437151274600346,
#           'lng': 78.45430121130967}],
#         'distance': 7816,
#         'postalCode': '500016',
#         'cc': 'IN',
#         'city': 'Hyderabad',
#         'state': 'Telangana',
#         'country': 'India',
#         'formattedAddress': ['Leelanagar (Begumpet)',
#          'Hyderabad 500016',
#          'Telangana',
#          'India']},
#        'categories': [{'id': '4bf58dd8d48988d145941735',
#          'name': 'Chinese Restaurant',
#          'pluralName': 'Chinese Restaurants',
#          'shortName': 'Chinese',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#           'suffix': '.png'},
#          'categoryCode': 13099,
#          'mapIcon': 'fsq-dining',
#          'mapTextColor': '#ff5c00',
#          'mapDarkTextColor': '#ffa66e',
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'createdAt': 1347469588},
#       'photo': {'id': '5a63886e47f8764d29d38143',
#        'createdAt': 1516472430,
#        'prefix': 'https://fastly.4sqi.net/img/general/',
#        'suffix': '/379615270_YiSMioC8nh1a_IHjkdmNbwbziY8EejG2-fibKllYG_g.jpg',
#        'width': 1440,
#        'height': 1920,
#        'visibility': 'public'},
#       'referralId': 'e-0-5050c114e4b0694f643d178e-12'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d20b3d7d7b0b1f771f0169f',
#        'name': 'Aqua',
#        'location': {'address': 'The park',
#         'lat': 17.42361173288638,
#         'lng': 78.46254087011502,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 17.42361173288638,
#           'lng': 78.46254087011502}],
#         'distance': 7375,
#         'cc': 'IN',
#         'city': 'Hyderabad',
#         'state': 'Telangana',
#         'country': 'India',
#         'formattedAddress': ['The park', 'Hyderabad', 'Telangana', 'India']},
#        'categories': [{'id': '4bf58dd8d48988d1d5941735',
#          'name': 'Hotel Bar',
#          'pluralName': 'Hotel Bars',
#          'shortName': 'Hotel Bar',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_bar_',
#           'suffix': '.png'},
#          'categoryCode': 13013,
#          'mapIcon': 'fsq-bar',
#          'mapTextColor': '#ff5c00',
#          'mapDarkTextColor': '#ffa66e',
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'createdAt': 1293988823},
#       'photo': {'id': '4f761904e4b015efa3f58ce2',
#        'createdAt': 1333139716,
#        'prefix': 'https://fastly.4sqi.net/img/general/',
#        'suffix': '/6QJK3r3LAX46kMPc-hkGfIwYrBkJhrsjd488DPFzHYM.jpg',
#        'width': 720,
#        'height': 537,
#        'visibility': 'public'},
#       'referralId': 'e-0-4d20b3d7d7b0b1f771f0169f-13'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '501647afe4b0be9af6342377',
#        'name': 'IMAX Screen',
#        'location': {'lat': 17.41304125821601,
#         'lng': 78.46561793041793,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 17.41304125821601,
#           'lng': 78.46561793041793}],
#         'distance': 7609,
#         'cc': 'IN',
#         'country': 'India',
#         'formattedAddress': ['India']},
#        'categories': [{'id': '4bf58dd8d48988d17f941735',
#          'name': 'Movie Theater',
#          'pluralName': 'Movie Theaters',
#          'shortName': 'Movie Theater',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/movietheater_',
#           'suffix': '.png'},
#          'categoryCode': 10024,
#          'mapIcon': 'fsq-arts-entertainment',
#          'mapTextColor': '#9162fe',
#          'mapDarkTextColor': '#d3bfff',
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'createdAt': 1343637423},
#       'photo': {'id': '50962de9e4b0f7ee4be18de2',
#        'createdAt': 1352019433,
#        'prefix': 'https://fastly.4sqi.net/img/general/',
#        'suffix': '/3291416_bqjhNySJSxNDO6UwutWxNAAquNREOcnkNjA22t4dT3o.jpg',
#        'width': 640,
#        'height': 488,
#        'visibility': 'public'},
#       'referralId': 'e-0-501647afe4b0be9af6342377-14'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '513afb90e4b04d69fd7cc3c7',
#        'name': 'Okra Restaurant',
#        'location': {'address': 'Opposite Hussain Sagar Lake',
#         'crossStreet': 'Tank Bund Road',
#         'lat': 17.423816625946916,
#         'lng': 78.48725662547521,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 17.423816625946916,
#           'lng': 78.48725662547521}],
#         'distance': 5024,
#         'postalCode': '500080',
#         'cc': 'IN',
#         'city': 'Hyderabad',
#         'state': 'Telangana',
#         'country': 'India',
#         'formattedAddress': ['Opposite Hussain Sagar Lake (Tank Bund Road)',
#          'Hyderabad 500080',
#          'Telangana',
#          'India']},
#        'categories': [{'id': '4d4b7105d754a06374d81259',
#          'name': 'Restaurant',
#          'pluralName': 'Restaurants',
#          'shortName': 'Restaurant',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'categoryCode': 13065,
#          'mapIcon': 'fsq-dining',
#          'mapTextColor': '#ff5c00',
#          'mapDarkTextColor': '#ffa66e',
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'createdAt': 1362819984},
#       'photo': {'id': '5bd91db2018cbb002c039b89',
#        'createdAt': 1540955570,
#        'prefix': 'https://fastly.4sqi.net/img/general/',
#        'suffix': '/1707767_NYLddACkHp5MJ1Vi_unRe073l2Vt1KPghHVQ2Mt492E.jpg',
#        'width': 1440,
#        'height': 1920,
#        'visibility': 'public'},
#       'referralId': 'e-0-513afb90e4b04d69fd7cc3c7-15'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4fad45d5e4b08e3811616235',
#        'name': 'Meridian Resturant',
#        'location': {'lat': 17.427354844491806,
#         'lng': 78.45215920349425,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 17.427354844491806,
#           'lng': 78.45215920349425}],
#         'distance': 8281,
#         'cc': 'IN',
#         'country': 'India',
#         'formattedAddress': ['India']},
#        'categories': [{'id': '4bf58dd8d48988d16e941735',
#          'name': 'Fast Food Restaurant',
#          'pluralName': 'Fast Food Restaurants',
#          'shortName': 'Fast Food',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#           'suffix': '.png'},
#          'categoryCode': 13145,
#          'mapIcon': 'fsq-dining',
#          'mapTextColor': '#ff5c00',
#          'mapDarkTextColor': '#ffa66e',
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'createdAt': 1336755669},
#       'photo': {'id': '5a8da9271fa76321017ba3d9',
#        'createdAt': 1519233319,
#        'prefix': 'https://fastly.4sqi.net/img/general/',
#        'suffix': '/1145948_WyJFKMBsBfQjzXwOQlwH9ccbZ4PTyEeBZ6ZnSv0hLtw.jpg',
#        'width': 1440,
#        'height': 1920,
#        'visibility': 'public'},
#       'referralId': 'e-0-4fad45d5e4b08e3811616235-16'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4dc4a65e18506de4adc5d5e5',
#        'name': 'Pragati',
#        'location': {'address': 'Kandaswamy Lane, Sultan Bazaar, Koti Andhra Pradesh, India',
#         'lat': 17.38808781386729,
#         'lng': 78.48113363131787,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 17.38808781386729,
#           'lng': 78.48113363131787}],
#         'distance': 8289,
#         'postalCode': '500095',
#         'cc': 'IN',
#         'city': 'Hyderabad',
#         'state': 'Telangana',
#         'country': 'India',
#         'formattedAddress': ['Kandaswamy Lane, Sultan Bazaar, Koti Andhra Pradesh, India',
#          'Hyderabad 500095',
#          'Telangana',
#          'India']},
#        'categories': [{'id': '54135bf5e4b08f3d2429dfde',
#          'name': 'South Indian Restaurant',
#          'pluralName': 'South Indian Restaurants',
#          'shortName': 'South Indian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'categoryCode': 13223,
#          'mapIcon': 'fsq-dining',
#          'mapTextColor': '#ff5c00',
#          'mapDarkTextColor': '#ffa66e',
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'createdAt': 1304733278},
#       'photo': {'id': '522ab9be11d21a4d76fb3426',
#        'createdAt': 1378531774,
#        'prefix': 'https://fastly.4sqi.net/img/general/',
#        'suffix': '/53656756_hcKP8yh00i2_HgVsBB_j5NJVWEOwkbAdYdNw-TUzWOE.jpg',
#        'width': 960,
#        'height': 720,
#        'visibility': 'public'},
#       'referralId': 'e-0-4dc4a65e18506de4adc5d5e5-17'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c680fe8e75ac9288aa2fbda',
#        'name': 'Cream Stone Concepts',
#        'location': {'address': 'Banjara Hills',
#         'crossStreet': 'Rd No 2',
#         'lat': 17.424802013516064,
#         'lng': 78.42195498785948,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 17.424802013516064,
#           'lng': 78.42195498785948}],
#         'distance': 11456,
#         'cc': 'IN',
#         'city': 'Hyderabad',
#         'state': 'Telangana',
#         'country': 'India',
#         'formattedAddress': ['Banjara Hills (Rd No 2)',
#          'Hyderabad',
#          'Telangana',
#          'India']},
#        'categories': [{'id': '4bf58dd8d48988d1c9941735',
#          'name': 'Ice Cream Parlor',
#          'pluralName': 'Ice Cream Parlors',
#          'shortName': 'Ice Cream',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/icecream_',
#           'suffix': '.png'},
#          'categoryCode': 13046,
#          'mapIcon': 'fsq-dessert',
#          'mapTextColor': '#ff5c00',
#          'mapDarkTextColor': '#ffa66e',
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'createdAt': 1281888232},
#       'photo': {'id': '539338d9498e2dfcdd9a4f77',
#        'createdAt': 1402157273,
#        'prefix': 'https://fastly.4sqi.net/img/general/',
#        'suffix': '/46963381_OgZjUarIp9HJXFm7n6vVKwbeD4Vczurxpe7Q3-AIMbQ.jpg',
#        'width': 540,
#        'height': 960,
#        'visibility': 'public'},
#       'referralId': 'e-0-4c680fe8e75ac9288aa2fbda-18'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4cc19bfb67a3b1f77a8dc90e',
#        'name': 'Chowmahala Palace',
#        'location': {'address': 'Moti Gali, Charminar',
#         'lat': 17.359299743829105,
#         'lng': 78.47161740649624,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 17.359299743829105,
#           'lng': 78.47161740649624}],
#         'distance': 11526,
#         'cc': 'IN',
#         'city': 'Hyderabad',
#         'state': 'Telangana',
#         'country': 'India',
#         'formattedAddress': ['Moti Gali, Charminar',
#          'Hyderabad',
#          'Telangana',
#          'India']},
#        'categories': [{'id': '4bf58dd8d48988d190941735',
#          'name': 'History Museum',
#          'pluralName': 'History Museums',
#          'shortName': 'History Museum',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/museum_history_',
#           'suffix': '.png'},
#          'categoryCode': 10030,
#          'mapIcon': 'fsq-arts-entertainment',
#          'mapTextColor': '#9162fe',
#          'mapDarkTextColor': '#d3bfff',
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'createdAt': 1287756795},
#       'photo': {'id': '51cc2328498e5c181957fb24',
#        'createdAt': 1372332840,
#        'prefix': 'https://fastly.4sqi.net/img/general/',
#        'suffix': '/5880181_raJgoo5mZrvuVn0EcdSZ8c-KVQh3tQF639_K4CLFOCw.jpg',
#        'width': 612,
#        'height': 612,
#        'visibility': 'public'},
#       'referralId': 'e-0-4cc19bfb67a3b1f77a8dc90e-19'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '50ab6b0ae4b0ade3441de450',
#        'name': 'Dimmy pan palace',
#        'location': {'address': 'sindhi colony',
#         'crossStreet': 'sindhi colony road',
#         'lat': 17.44008112919533,
#         'lng': 78.48429328395487,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 17.44008112919533,
#           'lng': 78.48429328395487}],
#         'distance': 4623,
#         'postalCode': '500040',
#         'cc': 'IN',
#         'city': 'Hyderabad',
#         'state': 'Telangana',
#         'country': 'India',
#         'formattedAddress': ['sindhi colony (sindhi colony road)',
#          'Hyderabad 500040',
#          'Telangana',
#          'India']},
#        'categories': [{'id': '4bf58dd8d48988d16a941735',
#          'name': 'Bakery',
#          'pluralName': 'Bakeries',
#          'shortName': 'Bakery',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#           'suffix': '.png'},
#          'categoryCode': 13002,
#          'mapIcon': 'fsq-bakery',
#          'mapTextColor': '#ff5c00',
#          'mapDarkTextColor': '#ffa66e',
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'createdAt': 1353411338},
#       'photo': {'id': '5a05f7c1a9e4025ba4bec70a',
#        'createdAt': 1510340545,
#        'prefix': 'https://fastly.4sqi.net/img/general/',
#        'suffix': '/456907541_UClD2BnnQX6e6wQYiyjJ8u8IPEHwgEa8KJtahuoTlSw.jpg',
#        'width': 1425,
#        'height': 1900,
#        'visibility': 'public'},
#       'referralId': 'e-0-50ab6b0ae4b0ade3441de450-20'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bcee9d1cc8cd13a5efdc4cf',
#        'name': 'Paradise Restaurant',
#        'location': {'address': 'Paradise Circle',
#         'lat': 17.44184420016073,
#         'lng': 78.48735433030141,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 17.44184420016073,
#           'lng': 78.48735433030141}],
#         'distance': 4268,
#         'postalCode': '500003',
#         'cc': 'IN',
#         'city': 'Secunderabad',
#         'state': 'Telangana',
#         'country': 'India',
#         'formattedAddress': ['Paradise Circle',
#          'Secunderabad 500003',
#          'Telangana',
#          'India']},
#        'categories': [{'id': '54135bf5e4b08f3d2429dfe6',
#          'name': 'Hyderabadi Restaurant',
#          'pluralName': 'Hyderabadi Restaurants',
#          'shortName': 'Hyderabadi',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'categoryCode': 13209,
#          'mapIcon': 'fsq-dining',
#          'mapTextColor': '#ff5c00',
#          'mapDarkTextColor': '#ffa66e',
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'createdAt': 1271851473},
#       'photo': {'id': '4fdad1cbe4b0631afd1fb442',
#        'createdAt': 1339740619,
#        'prefix': 'https://fastly.4sqi.net/img/general/',
#        'suffix': '/91C0R5BsvJ_yGKKsgiXMli0oWrW2Ci1gwXm2fC8gs_E.jpg',
#        'width': 720,
#        'height': 540,
#        'visibility': 'public'},
#       'referralId': 'e-0-4bcee9d1cc8cd13a5efdc4cf-21'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c053fc939d476b0b49732a7',
#        'name': 'Q-Mart',
#        'location': {'address': '5th Floor, Uptown Banjara, Road No 3, Banjara Hills',
#         'lat': 17.426681210355646,
#         'lng': 78.43861611809615,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 17.426681210355646,
#           'lng': 78.43861611809615}],
#         'distance': 9687,
#         'postalCode': '500034',
#         'cc': 'IN',
#         'neighborhood': 'Banjara Hills',
#         'city': 'Hyderabad',
#         'state': 'Telangana',
#         'country': 'India',
#         'formattedAddress': ['5th Floor, Uptown Banjara, Road No 3, Banjara Hills',
#          'Hyderabad 500034',
#          'Telangana',
#          'India']},
#        'categories': [{'id': '4bf58dd8d48988d1f6941735',
#          'name': 'Department Store',
#          'pluralName': 'Department Stores',
#          'shortName': 'Department Store',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/departmentstore_',
#           'suffix': '.png'},
#          'categoryCode': 17033,
#          'mapIcon': 'fsq-retail',
#          'mapTextColor': '#4285f4',
#          'mapDarkTextColor': '#91bafc',
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'createdAt': 1275412425},
#       'photo': {'id': '5149da1fe4b000e63448cc4a',
#        'createdAt': 1363794463,
#        'prefix': 'https://fastly.4sqi.net/img/general/',
#        'suffix': '/33074418_PJ3ERtMhNiFmNubyCz_C_68Tq1ffJ66ibqlVe1UIDbI.jpg',
#        'width': 640,
#        'height': 480,
#        'visibility': 'public'},
#       'referralId': 'e-0-4c053fc939d476b0b49732a7-22'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4cdd08d4fc973704fe47d905',
#        'name': 'Mayur Pan Shop',
#        'location': {'address': 'Hanuman Tekdi Rd.',
#         'lat': 17.388893979984353,
#         'lng': 78.48057795543552,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 17.388893979984353,
#           'lng': 78.48057795543552}],
#         'distance': 8252,
#         'postalCode': '500001',
#         'cc': 'IN',
#         'city': 'Hyderabad',
#         'state': 'Telangana',
#         'country': 'India',
#         'formattedAddress': ['Hanuman Tekdi Rd.',
#          'Hyderabad 500001',
#          'Telangana',
#          'India']},
#        'categories': [{'id': '4bf58dd8d48988d112941735',
#          'name': 'Juice Bar',
#          'pluralName': 'Juice Bars',
#          'shortName': 'Juice Bar',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/juicebar_',
#           'suffix': '.png'},
#          'categoryCode': 13059,
#          'mapIcon': 'fsq-dining',
#          'mapTextColor': '#ff5c00',
#          'mapDarkTextColor': '#ffa66e',
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'createdAt': 1289554132},
#       'photo': {'id': '5072ce20e4b0359dfb8cd73b',
#        'createdAt': 1349701152,
#        'prefix': 'https://fastly.4sqi.net/img/general/',
#        'suffix': '/20471134__D-RxgL7IISFGXYwLeNkjeV2odTZxr37T6vHUPIWnDc.jpg',
#        'width': 540,
#        'height': 720,
#        'visibility': 'public'},
#       'referralId': 'e-0-4cdd08d4fc973704fe47d905-23'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bc97fc50687ef3b0612dacc',
#        'name': 'GVK One',
#        'location': {'address': 'Banjara Hills',
#         'crossStreet': 'Rd No 1',
#         'lat': 17.419411036100108,
#         'lng': 78.44806879531454,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 17.419411036100108,
#           'lng': 78.44806879531454}],
#         'distance': 8977,
#         'postalCode': '500034',
#         'cc': 'IN',
#         'city': 'Hyderabad',
#         'state': 'Telangana',
#         'country': 'India',
#         'formattedAddress': ['Banjara Hills (Rd No 1)',
#          'Hyderabad 500034',
#          'Telangana',
#          'India']},
#        'categories': [{'id': '4bf58dd8d48988d1fd941735',
#          'name': 'Shopping Mall',
#          'pluralName': 'Shopping Malls',
#          'shortName': 'Mall',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/mall_',
#           'suffix': '.png'},
#          'categoryCode': 17114,
#          'mapIcon': 'fsq-default',
#          'mapTextColor': '#72767f',
#          'mapDarkTextColor': '#d5d7da',
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'createdAt': 1271496645},
#       'photo': {'id': '50d0423ce4b03e4b514dcecf',
#        'createdAt': 1355825724,
#        'prefix': 'https://fastly.4sqi.net/img/general/',
#        'suffix': '/16464317_tXUhUIeHaw1fAPQ2M1xDWnbXKKGKOkvGOZ0Q-kAexfk.jpg',
#        'width': 612,
#        'height': 612,
#        'visibility': 'public'},
#       'referralId': 'e-0-4bc97fc50687ef3b0612dacc-24'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4cdff998f8a4a143e59ee1bc',
#        'name': 'Pizza Den',
#        'location': {'address': 'Penderghast Road',
#         'crossStreet': 'Opposite Wesley High School',
#         'lat': 17.44075847619752,
#         'lng': 78.48671832238533,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 17.44075847619752,
#           'lng': 78.48671832238533}],
#         'distance': 4356,
#         'postalCode': '500003',
#         'cc': 'IN',
#         'city': 'Secunderabad',
#         'state': 'Telangana',
#         'country': 'India',
#         'formattedAddress': ['Penderghast Road (Opposite Wesley High School)',
#          'Secunderabad 500003',
#          'Telangana',
#          'India']},
#        'categories': [{'id': '4bf58dd8d48988d1ca941735',
#          'name': 'Pizzeria',
#          'pluralName': 'Pizzerias',
#          'shortName': 'Pizza',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#           'suffix': '.png'},
#          'categoryCode': 13064,
#          'mapIcon': 'fsq-pizza',
#          'mapTextColor': '#ff5c00',
#          'mapDarkTextColor': '#ffa66e',
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'createdAt': 1289746840},
#       'photo': {'id': '5991bcc086f4cc10e207466c',
#        'createdAt': 1502723264,
#        'prefix': 'https://fastly.4sqi.net/img/general/',
#        'suffix': '/11033725_OPS1uNB3CpHqJFU-Qtfcb8hyR2kQ6jXfAisg3iwnX0E.jpg',
#        'width': 1900,
#        'height': 1425,
#        'visibility': 'public'},
#       'referralId': 'e-0-4cdff998f8a4a143e59ee1bc-25'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4e009da21838cb6a1acb225e',
#        'name': 'Minerva Coffee Shop',
#        'location': {'address': 'Himyathnagar',
#         'lat': 17.40140986703394,
#         'lng': 78.48567190017107,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 17.40140986703394,
#           'lng': 78.48567190017107}],
#         'distance': 6823,
#         'postalCode': '500029',
#         'cc': 'IN',
#         'city': 'Hyderabad',
#         'state': 'Telangana',
#         'country': 'India',
#         'formattedAddress': ['Himyathnagar',
#          'Hyderabad 500029',
#          'Telangana',
#          'India']},
#        'categories': [{'id': '4bf58dd8d48988d10f941735',
#          'name': 'Indian Restaurant',
#          'pluralName': 'Indian Restaurants',
#          'shortName': 'Indian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#           'suffix': '.png'},
#          'categoryCode': 13199,
#          'mapIcon': 'fsq-dining',
#          'mapTextColor': '#ff5c00',
#          'mapDarkTextColor': '#ffa66e',
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'createdAt': 1308663202},
#       'photo': {'id': '4fa93723e4b0f380f2e08c72',
#        'createdAt': 1336489763,
#        'prefix': 'https://fastly.4sqi.net/img/general/',
#        'suffix': '/htThFfiRZYGhv7pVmp1-LqCLHuL48M5-SBQLl91BGX8.jpg',
#        'width': 537,
#        'height': 720,
#        'visibility': 'public'},
#       'referralId': 'e-0-4e009da21838cb6a1acb225e-26'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c642d01eb82d13a1fa809d6',
#        'name': 'Shadaab',
#        'location': {'lat': 17.368661119712183,
#         'lng': 78.4755724156713,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 17.368661119712183,
#           'lng': 78.4755724156713}],
#         'distance': 10417,
#         'cc': 'IN',
#         'city': 'Hyderabad',
#         'state': 'Telangana',
#         'country': 'India',
#         'formattedAddress': ['Hyderabad', 'Telangana', 'India']},
#        'categories': [{'id': '4bf58dd8d48988d147941735',
#          'name': 'Diner',
#          'pluralName': 'Diners',
#          'shortName': 'Diner',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/diner_',
#           'suffix': '.png'},
#          'categoryCode': 13049,
#          'mapIcon': 'fsq-dining',
#          'mapTextColor': '#ff5c00',
#          'mapDarkTextColor': '#ffa66e',
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'createdAt': 1281633537},
#       'photo': {'id': '5c18bf0e2aff31002c36ec1d',
#        'createdAt': 1545125646,
#        'prefix': 'https://fastly.4sqi.net/img/general/',
#        'suffix': '/43211711_U49W-KvhzqL1R5tzTNdBnYSkty8oyGdRKEsQpBLw2Ck.jpg',
#        'width': 1440,
#        'height': 1920,
#        'visibility': 'public'},
#       'referralId': 'e-0-4c642d01eb82d13a1fa809d6-27'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d5fadf029ef236a85a09b59',
#        'name': 'Cafe Niloufer & Bakers',
#        'location': {'address': 'Red Hills Rd, Opp Hanuman Temple',
#         'crossStreet': 'Lakdikapul',
#         'lat': 17.399714984098786,
#         'lng': 78.46288084900512,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 17.399714984098786,
#           'lng': 78.46288084900512}],
#         'distance': 8697,
#         'postalCode': '500004',
#         'cc': 'IN',
#         'city': 'Hyderabad',
#         'state': 'Telangana',
#         'country': 'India',
# ...
#        'width': 1425,
#        'height': 1900,
#        'visibility': 'public'},
#       'referralId': 'e-0-56e18d05498e7b9a3ac1d2c2-89'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d85bc84353060fc83aa0be3',
#        'name': 'Novotel Hyderabad Convention Centre',
#        'location': {'address': 'Near Hitec City, P.O Bag 1101, Kondapur',
#         'crossStreet': 'Near Hitec City',
#         'lat': 17.4728994,
#         'lng': 78.3737955,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 17.4728994,
#           'lng': 78.3737955}],
#         'distance': 16491,
#         'postalCode': '500081',
#         'cc': 'IN',
#         'city': 'Hyderabad',
#         'state': 'Telangana',
#         'country': 'India',
#         'formattedAddress': ['Near Hitec City, P.O Bag 1101, Kondapur (Near Hitec City)',
#          'Hyderabad 500081',
#          'Telangana',
#          'India']},
#        'categories': [{'id': '4bf58dd8d48988d1fa931735',
#          'name': 'Hotel',
#          'pluralName': 'Hotels',
#          'shortName': 'Hotel',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#           'suffix': '.png'},
#          'categoryCode': 19014,
#          'mapIcon': 'fsq-lodging',
#          'mapTextColor': '#4285f4',
#          'mapDarkTextColor': '#91bafc',
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'createdAt': 1300610180},
#       'photo': {'id': '523c1d2011d28c7473f99e8f',
#        'createdAt': 1379671328,
#        'prefix': 'https://fastly.4sqi.net/img/general/',
#        'suffix': '/43938617_XDac8G_6MJIXZxu1WhOyXsjZN82qujpsSc46lr5XvSw.jpg',
#        'width': 958,
#        'height': 720,
#        'visibility': 'public'},
#       'referralId': 'e-0-4d85bc84353060fc83aa0be3-90'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '57b60e51498e5f6a7af5dac7',
#        'name': 'DRIVEN CAFE',
#        'location': {'lat': 17.422014480942593,
#         'lng': 78.33835141925407,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 17.422014480942593,
#           'lng': 78.33835141925407}],
#         'distance': 20244,
#         'cc': 'IN',
#         'city': 'Hyderabad',
#         'state': 'Telangana',
#         'country': 'India',
#         'formattedAddress': ['Hyderabad', 'Telangana', 'India']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'categoryCode': 13035,
#          'mapIcon': 'fsq-coffee',
#          'mapTextColor': '#ff5c00',
#          'mapDarkTextColor': '#ffa66e',
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'createdAt': 1471549009},
#       'photo': {'id': '5d50e39aebe3bf0007e7ecdf',
#        'createdAt': 1565582234,
#        'prefix': 'https://fastly.4sqi.net/img/general/',
#        'suffix': '/5100854_kD8cyXBfIPc7s0OrlngTsv6aqtjMSBnif5ZG7n5K2EM.jpg',
#        'width': 1440,
#        'height': 1920,
#        'visibility': 'public'},
#       'referralId': 'e-0-57b60e51498e5f6a7af5dac7-91'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '51f76fb9498ed61c0a16f1b9',
#        'name': 'Decathlon Sports Store',
#        'location': {'lat': 17.24236966601028,
#         'lng': 78.43479804531336,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 17.24236966601028,
#           'lng': 78.43479804531336}],
#         'distance': 24935,
#         'cc': 'IN',
#         'country': 'India',
#         'formattedAddress': ['India']},
#        'categories': [{'id': '4bf58dd8d48988d1f2941735',
#          'name': 'Sporting Goods Retail',
#          'pluralName': 'Sporting Goods Retail',
#          'shortName': 'Sporting Goods Retail',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/sports_outdoors_',
#           'suffix': '.png'},
#          'categoryCode': 17117,
#          'mapIcon': 'fsq-default',
#          'mapTextColor': '#72767f',
#          'mapDarkTextColor': '#d5d7da',
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'createdAt': 1375170489},
#       'photo': {'id': '5b13b9a2b9a5a8002cdc7322',
#        'createdAt': 1528019362,
#        'prefix': 'https://fastly.4sqi.net/img/general/',
#        'suffix': '/1145948_H_d84x4X4j_jLQE6WKkEyfbGmNpxOYHGYL2Xkf_YMfI.jpg',
#        'width': 1920,
#        'height': 1440,
#        'visibility': 'public'},
#       'referralId': 'e-0-51f76fb9498ed61c0a16f1b9-92'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '54317905498ed37e3c280c0e',
#        'name': 'PVR Cinemas',
#        'location': {'address': 'Forum Mall',
#         'crossStreet': 'Kukatpally',
#         'lat': 17.483858424533327,
#         'lng': 78.38887728539942,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 17.483858424533327,
#           'lng': 78.38887728539942}],
#         'distance': 15185,
#         'postalCode': '500072',
#         'cc': 'IN',
#         'city': 'Hyderabad',
#         'state': 'Telangana',
#         'country': 'India',
#         'formattedAddress': ['Forum Mall (Kukatpally)',
#          'Hyderabad 500072',
#          'Telangana',
#          'India']},
#        'categories': [{'id': '4bf58dd8d48988d17f941735',
#          'name': 'Movie Theater',
#          'pluralName': 'Movie Theaters',
#          'shortName': 'Movie Theater',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/movietheater_',
#           'suffix': '.png'},
#          'categoryCode': 10024,
#          'mapIcon': 'fsq-arts-entertainment',
#          'mapTextColor': '#9162fe',
#          'mapDarkTextColor': '#d3bfff',
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'createdAt': 1412528389},
#       'photo': {'id': '682774ca99f7891203a12949',
#        'createdAt': 1747416266,
#        'prefix': 'https://fastly.4sqi.net/img/general/',
#        'suffix': '/27127047_sn5aDfPE_mO_ocy9oxa2GyjuXUJwj-5LfHJgAatCafM.jpg',
#        'width': 1440,
#        'height': 1920,
#        'visibility': 'public'},
#       'referralId': 'e-0-54317905498ed37e3c280c0e-93'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c9f3cd403133704825070d5',
#        'name': 'Maharaja Chat Bandar',
#        'location': {'address': 'Madhapur',
#         'lat': 17.44095403732893,
#         'lng': 78.39679571498786,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 17.44095403732893,
#           'lng': 78.39679571498786}],
#         'distance': 13847,
#         'cc': 'IN',
#         'city': 'Hyderabad',
#         'state': 'Telangana',
#         'country': 'India',
#         'formattedAddress': ['Madhapur', 'Hyderabad', 'Telangana', 'India']},
#        'categories': [{'id': '4bf58dd8d48988d1c7941735',
#          'name': 'Snack Place',
#          'pluralName': 'Snack Places',
#          'shortName': 'Snacks',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/snacks_',
#           'suffix': '.png'},
#          'categoryCode': 13382,
#          'mapIcon': 'fsq-dessert',
#          'mapTextColor': '#ff5c00',
#          'mapDarkTextColor': '#ffa66e',
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'createdAt': 1285504212},
#       'photo': {'id': '51bdb0f1498ee5622bb6e8ba',
#        'createdAt': 1371386097,
#        'prefix': 'https://fastly.4sqi.net/img/general/',
#        'suffix': '/11510967_srCR8MJkAo7TH5AWUXMBXbqu4_2z_E7SsI5ElQ40vIQ.jpg',
#        'width': 540,
#        'height': 960,
#        'visibility': 'public'},
#       'referralId': 'e-0-4c9f3cd403133704825070d5-94'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5bdd97f61a2925002549b87c',
#        'name': 'Sarath City Capital',
#        'location': {'lat': 17.457403928803846,
#         'lng': 78.36385751297978,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 17.457403928803846,
#           'lng': 78.36385751297978}],
#         'distance': 17349,
#         'cc': 'IN',
#         'city': 'Hyderabad',
#         'state': 'Telangana',
#         'country': 'India',
#         'formattedAddress': ['Hyderabad', 'Telangana', 'India']},
#        'categories': [{'id': '4bf58dd8d48988d1fd941735',
#          'name': 'Shopping Mall',
#          'pluralName': 'Shopping Malls',
#          'shortName': 'Mall',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/mall_',
#           'suffix': '.png'},
#          'categoryCode': 17114,
#          'mapIcon': 'fsq-default',
#          'mapTextColor': '#72767f',
#          'mapDarkTextColor': '#d5d7da',
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'createdAt': 1541249014},
#       'photo': {'id': '681f09539d5f152b1b343810',
#        'createdAt': 1746864467,
#        'prefix': 'https://fastly.4sqi.net/img/general/',
#        'suffix': '/586212632_-_D9RM1XSADJx1YG-N6_KNKl8UqDysMiQ1K1bzBz71o.jpg',
#        'width': 1440,
#        'height': 1920,
#        'visibility': 'public'},
#       'referralId': 'e-0-5bdd97f61a2925002549b87c-95'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4e58e6beae6099fc00bf8058',
#        'name': 'Ramoji Film City',
#        'location': {'lat': 17.30983890015597,
#         'lng': 78.68187936558887,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 17.30983890015597,
#           'lng': 78.68187936558887}],
#         'distance': 22554,
#         'cc': 'IN',
#         'city': 'Pochampalle',
#         'state': 'Andhra Pradesh',
#         'country': 'India',
#         'formattedAddress': ['Pochampalle', 'Andhra Pradesh', 'India']},
#        'categories': [{'id': '4bf58dd8d48988d182941735',
#          'name': 'Amusement Park',
#          'pluralName': 'Amusement Parks',
#          'shortName': 'Amusement Park',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/themepark_',
#           'suffix': '.png'},
#          'categoryCode': 10001,
#          'mapIcon': 'fsq-arts-entertainment',
#          'mapTextColor': '#9162fe',
#          'mapDarkTextColor': '#d3bfff',
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'createdAt': 1314449086},
#       'photo': {'id': '50a08742e4b0bae036bcc7da',
#        'createdAt': 1352697666,
#        'prefix': 'https://fastly.4sqi.net/img/general/',
#        'suffix': '/9174823_OEnBuj3myQrnEwqSYvEnVentGNyGu8v3w_0WOl5fYxs.jpg',
#        'width': 720,
#        'height': 540,
#        'visibility': 'public'},
#       'referralId': 'e-0-4e58e6beae6099fc00bf8058-96'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4e3574e362e17d290833ba27',
#        'name': 'Bhel Township',
#        'location': {'lat': 17.495007109631313,
#         'lng': 78.30345850467941,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 17.495007109631313,
#           'lng': 78.30345850467941}],
#         'distance': 24292,
#         'cc': 'IN',
#         'city': 'Hyderabad',
#         'state': 'Telangana',
#         'country': 'India',
#         'formattedAddress': ['Hyderabad', 'Telangana', 'India']},
#        'categories': [{'id': '4d4b7105d754a06377d81259',
#          'name': 'Landmarks and Outdoors',
#          'pluralName': 'Landmarks and Outdoors',
#          'shortName': 'Landmarks and Outdoors',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/default_',
#           'suffix': '.png'},
#          'categoryCode': 16000,
#          'mapIcon': 'fsq-default',
#          'mapTextColor': '#72767f',
#          'mapDarkTextColor': '#d5d7da',
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'createdAt': 1312126179},
#       'photo': {'id': '549b980b498e74a0fcbecb57',
#        'createdAt': 1419483147,
#        'prefix': 'https://fastly.4sqi.net/img/general/',
#        'suffix': '/106972738_yvd9vHXilr7eGP7-y2DcSW9GAH620vrMDLP675LSc8U.jpg',
#        'width': 1920,
#        'height': 1440,
#        'visibility': 'public'},
#       'referralId': 'e-0-4e3574e362e17d290833ba27-97'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4e4514281495455b10d4ec60',
#        'name': 'Sitara Hotel',
#        'location': {'address': 'Ramoji Film City',
#         'lat': 17.26021217265053,
#         'lng': 78.67872927328446,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 17.26021217265053,
#           'lng': 78.67872927328446}],
#         'distance': 26434,
#         'cc': 'IN',
#         'city': 'Hyderabad',
#         'state': 'Telangana',
#         'country': 'India',
#         'formattedAddress': ['Ramoji Film City',
#          'Hyderabad',
#          'Telangana',
#          'India']},
#        'categories': [{'id': '4bf58dd8d48988d1fa931735',
#          'name': 'Hotel',
#          'pluralName': 'Hotels',
#          'shortName': 'Hotel',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#           'suffix': '.png'},
#          'categoryCode': 19014,
#          'mapIcon': 'fsq-lodging',
#          'mapTextColor': '#4285f4',
#          'mapDarkTextColor': '#91bafc',
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'createdAt': 1313149992},
#       'photo': {'id': '62224546cead7256f5092b71',
#        'createdAt': 1646413126,
#        'prefix': 'https://fastly.4sqi.net/img/general/',
#        'suffix': '/494681569_7Iurjqy3u17rXUJ55V6pQQVB-uCmNI5hIJ1KuQRo25Y.jpg',
#        'width': 1440,
#        'height': 1920,
#        'visibility': 'public'},
#       'referralId': 'e-0-4e4514281495455b10d4ec60-98'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ea961860aaff9d3d576a354',
#        'name': 'Masqati',
#        'location': {'lat': 17.282319902708846,
#         'lng': 78.58729857419705,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 17.282319902708846,
#           'lng': 78.58729857419705}],
#         'distance': 19564,
#         'cc': 'IN',
#         'state': 'Uttar Pradesh',
#         'country': 'India',
#         'formattedAddress': ['Uttar Pradesh', 'India']},
#        'categories': [{'id': '4bf58dd8d48988d1c9941735',
#          'name': 'Ice Cream Parlor',
#          'pluralName': 'Ice Cream Parlors',
#          'shortName': 'Ice Cream',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/icecream_',
#           'suffix': '.png'},
#          'categoryCode': 13046,
#          'mapIcon': 'fsq-dessert',
#          'mapTextColor': '#ff5c00',
#          'mapDarkTextColor': '#ffa66e',
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'createdAt': 1319723398},
#       'photo': {'id': '56409f21cd10405a38e29c98',
#        'createdAt': 1447075617,
#        'prefix': 'https://fastly.4sqi.net/img/general/',
#        'suffix': '/58757969_J51FL2CMk5hmuHhgR5wUXroY0nkm-hBqCT-V6nH2x3A.jpg',
#        'width': 1440,
#        'height': 1920,
#        'visibility': 'public'},
#       'referralId': 'e-0-4ea961860aaff9d3d576a354-99'}]}]}}

# %%
venues = results['response']['groups'][0]['items']
nearby_venues = json_normalize(venues)

# %%
nearby_venues
# Out:
#                          referralId  reasons.count  \
# 0    e-0-4bac7d4df964a5205df73ae3-0              0
# 1    e-0-4e1b27cbd22ddd4af9ea6366-1              0
# 2    e-0-4c68e4238d22c928e6f2b545-2              0
# 3    e-0-4c1f7229b306c928046b68b7-3              0
# 4    e-0-4df9c65c62e1e9a24367f9e5-4              0
# ..                              ...            ...
# 95  e-0-5bdd97f61a2925002549b87c-95              0
# 96  e-0-4e58e6beae6099fc00bf8058-96              0
# 97  e-0-4e3574e362e17d290833ba27-97              0
# 98  e-0-4e4514281495455b10d4ec60-98              0
# 99  e-0-4ea961860aaff9d3d576a354-99              0
#
#                                         reasons.items  \
# 0   [{'summary': 'This spot is popular', 'type': '...
# 1   [{'summary': 'This spot is popular', 'type': '...
# 2   [{'summary': 'This spot is popular', 'type': '...
# 3   [{'summary': 'This spot is popular', 'type': '...
# 4   [{'summary': 'This spot is popular', 'type': '...
# ..                                                ...
# 95  [{'summary': 'This spot is popular', 'type': '...
# 96  [{'summary': 'This spot is popular', 'type': '...
# 97  [{'summary': 'This spot is popular', 'type': '...
# 98  [{'summary': 'This spot is popular', 'type': '...
# 99  [{'summary': 'This spot is popular', 'type': '...
#
#                     venue.id           venue.name  \
# 0   4bac7d4df964a5205df73ae3    10 Downing Street
# 1   4e1b27cbd22ddd4af9ea6366         ITC Kakatiya
# 2   4c68e4238d22c928e6f2b545    Secunderabad Club
# 3   4c1f7229b306c928046b68b7  Fifth Avenue Bakers
# 4   4df9c65c62e1e9a24367f9e5      King & Cardinal
# ..                       ...                  ...
# 95  5bdd97f61a2925002549b87c  Sarath City Capital
# 96  4e58e6beae6099fc00bf8058     Ramoji Film City
# 97  4e3574e362e17d290833ba27        Bhel Township
# 98  4e4514281495455b10d4ec60         Sitara Hotel
# 99  4ea961860aaff9d3d576a354              Masqati
#
#                           venue.location.address  \
# 0   Ground Floor, Lifestyle Building, Greenlands
# 1                           6 -3 -1187, Begumpet
# 2                                         Picket
# 3                                     Sainikpuri
# 4                                   Himayatnagar
# ..                                           ...
# 95                                           NaN
# 96                                           NaN
# 97                                           NaN
# 98                              Ramoji Film City
# 99                                           NaN
#
#            venue.location.crossStreet  venue.location.lat  venue.location.lng  \
# 0                         Begumpet Rd           17.435868           78.457443
# 1                            Begumpet           17.432514           78.457353
# 2                                 NaN           17.452548           78.497400
# 3                                 NaN           17.487673           78.542793
# 4   Narayanguda-himayat Nagar X Roads           17.400678           78.488575
# ..                                ...                 ...                 ...
# 95                                NaN           17.457404           78.363858
# 96                                NaN           17.309839           78.681879
# 97                                NaN           17.495007           78.303459
# 98                                NaN           17.260212           78.678729
# 99                                NaN           17.282320           78.587299
#
#                         venue.location.labeledLatLngs  ...  venue.createdAt  \
# 0   [{'label': 'display', 'lat': 17.43586817493973...  ...       1269595469
# 1   [{'label': 'display', 'lat': 17.43251403198251...  ...       1310402507
# 2   [{'label': 'display', 'lat': 17.45254801837352...  ...       1281942563
# 3   [{'label': 'display', 'lat': 17.48767334633119...  ...       1277129257
# 4   [{'label': 'display', 'lat': 17.40067830505242...  ...       1308214876
# ..                                                ...  ...              ...
# 95  [{'label': 'display', 'lat': 17.45740392880384...  ...       1541249014
# 96  [{'label': 'display', 'lat': 17.30983890015597...  ...       1314449086
# 97  [{'label': 'display', 'lat': 17.49500710963131...  ...       1312126179
# 98  [{'label': 'display', 'lat': 17.26021217265053...  ...       1313149992
# 99  [{'label': 'display', 'lat': 17.28231990270884...  ...       1319723398
#
#                     photo.id photo.createdAt  \
# 0   529388ce498ec78f1904dd61      1385400526
# 1   5039d2cfe4b08256fb6f9235      1345966799
# 2   61d854c052dc4a469d721467      1641567424
# 3   5410601c11d2a80070a4d902      1410359324
# 4   511f9153e4b0841ee067e14a      1361023315
# ..                       ...             ...
# 95  681f09539d5f152b1b343810      1746864467
# 96  50a08742e4b0bae036bcc7da      1352697666
# 97  549b980b498e74a0fcbecb57      1419483147
# 98  62224546cead7256f5092b71      1646413126
# 99  56409f21cd10405a38e29c98      1447075617
#
#                             photo.prefix  \
# 0   https://fastly.4sqi.net/img/general/
# 1   https://fastly.4sqi.net/img/general/
# 2   https://fastly.4sqi.net/img/general/
# 3   https://fastly.4sqi.net/img/general/
# 4   https://fastly.4sqi.net/img/general/
# ..                                   ...
# 95  https://fastly.4sqi.net/img/general/
# 96  https://fastly.4sqi.net/img/general/
# 97  https://fastly.4sqi.net/img/general/
# 98  https://fastly.4sqi.net/img/general/
# 99  https://fastly.4sqi.net/img/general/
#
#                                          photo.suffix photo.width  \
# 0   /32609040_X0yOzEI5oGptuXM0aoHecUKM9ssqdHLfHNHF...         970
# 1    /jIxkFJ4NX8zo6es-KAJUljhtdjADHd8Et-kT5Q8t_oQ.jpg         612
# 2   /36980127_TRsV_zibmCz5rS1m3cHu5qywc8p1w3d19zO-...        1920
# 3   /58807053_Az0izB4nYIHej7aiec35wqyHdb71ssAD5yHm...         540
# 4   /40470832_8JS8r4wwSPHFEIT1zrQnB9cEBP7CykzzHPht...         960
# ..                                                ...         ...
# 95  /586212632_-_D9RM1XSADJx1YG-N6_KNKl8UqDysMiQ1K...        1440
# 96  /9174823_OEnBuj3myQrnEwqSYvEnVentGNyGu8v3w_0WO...         720
# 97  /106972738_yvd9vHXilr7eGP7-y2DcSW9GAH620vrMDLP...        1920
# 98  /494681569_7Iurjqy3u17rXUJ55V6pQQVB-uCmNI5hIJ1...        1440
# 99  /58757969_J51FL2CMk5hmuHhgR5wUXroY0nkm-hBqCT-V...        1440
#
#    photo.height photo.visibility  venue.location.neighborhood  \
# 0           650           public                          NaN
# 1           612           public                          NaN
# 2          1440           public                          NaN
# 3           960           public                          NaN
# 4           540           public                          NaN
# ..          ...              ...                          ...
# 95         1920           public                          NaN
# 96          540           public                          NaN
# 97         1440           public                          NaN
# 98         1920           public                          NaN
# 99         1920           public                          NaN
#
#    venue.venuePage.id
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
# ..                ...
# 95                NaN
# 96                NaN
# 97                NaN
# 98                NaN
# 99                NaN
#
# [100 rows x 30 columns]

# %%
nearby_venues
# Out:
#                          referralId  reasons.count  \
# 0    e-0-4bac7d4df964a5205df73ae3-0              0
# 1    e-0-4e1b27cbd22ddd4af9ea6366-1              0
# 2    e-0-4c68e4238d22c928e6f2b545-2              0
# 3    e-0-4c1f7229b306c928046b68b7-3              0
# 4    e-0-4df9c65c62e1e9a24367f9e5-4              0
# ..                              ...            ...
# 95  e-0-5bdd97f61a2925002549b87c-95              0
# 96  e-0-4e58e6beae6099fc00bf8058-96              0
# 97  e-0-4e3574e362e17d290833ba27-97              0
# 98  e-0-4e4514281495455b10d4ec60-98              0
# 99  e-0-4ea961860aaff9d3d576a354-99              0
#
#                                         reasons.items  \
# 0   [{'summary': 'This spot is popular', 'type': '...
# 1   [{'summary': 'This spot is popular', 'type': '...
# 2   [{'summary': 'This spot is popular', 'type': '...
# 3   [{'summary': 'This spot is popular', 'type': '...
# 4   [{'summary': 'This spot is popular', 'type': '...
# ..                                                ...
# 95  [{'summary': 'This spot is popular', 'type': '...
# 96  [{'summary': 'This spot is popular', 'type': '...
# 97  [{'summary': 'This spot is popular', 'type': '...
# 98  [{'summary': 'This spot is popular', 'type': '...
# 99  [{'summary': 'This spot is popular', 'type': '...
#
#                     venue.id           venue.name  \
# 0   4bac7d4df964a5205df73ae3    10 Downing Street
# 1   4e1b27cbd22ddd4af9ea6366         ITC Kakatiya
# 2   4c68e4238d22c928e6f2b545    Secunderabad Club
# 3   4c1f7229b306c928046b68b7  Fifth Avenue Bakers
# 4   4df9c65c62e1e9a24367f9e5      King & Cardinal
# ..                       ...                  ...
# 95  5bdd97f61a2925002549b87c  Sarath City Capital
# 96  4e58e6beae6099fc00bf8058     Ramoji Film City
# 97  4e3574e362e17d290833ba27        Bhel Township
# 98  4e4514281495455b10d4ec60         Sitara Hotel
# 99  4ea961860aaff9d3d576a354              Masqati
#
#                           venue.location.address  \
# 0   Ground Floor, Lifestyle Building, Greenlands
# 1                           6 -3 -1187, Begumpet
# 2                                         Picket
# 3                                     Sainikpuri
# 4                                   Himayatnagar
# ..                                           ...
# 95                                           NaN
# 96                                           NaN
# 97                                           NaN
# 98                              Ramoji Film City
# 99                                           NaN
#
#            venue.location.crossStreet  venue.location.lat  venue.location.lng  \
# 0                         Begumpet Rd           17.435868           78.457443
# 1                            Begumpet           17.432514           78.457353
# 2                                 NaN           17.452548           78.497400
# 3                                 NaN           17.487673           78.542793
# 4   Narayanguda-himayat Nagar X Roads           17.400678           78.488575
# ..                                ...                 ...                 ...
# 95                                NaN           17.457404           78.363858
# 96                                NaN           17.309839           78.681879
# 97                                NaN           17.495007           78.303459
# 98                                NaN           17.260212           78.678729
# 99                                NaN           17.282320           78.587299
#
#                         venue.location.labeledLatLngs  ...  venue.createdAt  \
# 0   [{'label': 'display', 'lat': 17.43586817493973...  ...       1269595469
# 1   [{'label': 'display', 'lat': 17.43251403198251...  ...       1310402507
# 2   [{'label': 'display', 'lat': 17.45254801837352...  ...       1281942563
# 3   [{'label': 'display', 'lat': 17.48767334633119...  ...       1277129257
# 4   [{'label': 'display', 'lat': 17.40067830505242...  ...       1308214876
# ..                                                ...  ...              ...
# 95  [{'label': 'display', 'lat': 17.45740392880384...  ...       1541249014
# 96  [{'label': 'display', 'lat': 17.30983890015597...  ...       1314449086
# 97  [{'label': 'display', 'lat': 17.49500710963131...  ...       1312126179
# 98  [{'label': 'display', 'lat': 17.26021217265053...  ...       1313149992
# 99  [{'label': 'display', 'lat': 17.28231990270884...  ...       1319723398
#
#                     photo.id photo.createdAt  \
# 0   529388ce498ec78f1904dd61      1385400526
# 1   5039d2cfe4b08256fb6f9235      1345966799
# 2   61d854c052dc4a469d721467      1641567424
# 3   5410601c11d2a80070a4d902      1410359324
# 4   511f9153e4b0841ee067e14a      1361023315
# ..                       ...             ...
# 95  681f09539d5f152b1b343810      1746864467
# 96  50a08742e4b0bae036bcc7da      1352697666
# 97  549b980b498e74a0fcbecb57      1419483147
# 98  62224546cead7256f5092b71      1646413126
# 99  56409f21cd10405a38e29c98      1447075617
#
#                             photo.prefix  \
# 0   https://fastly.4sqi.net/img/general/
# 1   https://fastly.4sqi.net/img/general/
# 2   https://fastly.4sqi.net/img/general/
# 3   https://fastly.4sqi.net/img/general/
# 4   https://fastly.4sqi.net/img/general/
# ..                                   ...
# 95  https://fastly.4sqi.net/img/general/
# 96  https://fastly.4sqi.net/img/general/
# 97  https://fastly.4sqi.net/img/general/
# 98  https://fastly.4sqi.net/img/general/
# 99  https://fastly.4sqi.net/img/general/
#
#                                          photo.suffix photo.width  \
# 0   /32609040_X0yOzEI5oGptuXM0aoHecUKM9ssqdHLfHNHF...         970
# 1    /jIxkFJ4NX8zo6es-KAJUljhtdjADHd8Et-kT5Q8t_oQ.jpg         612
# 2   /36980127_TRsV_zibmCz5rS1m3cHu5qywc8p1w3d19zO-...        1920
# 3   /58807053_Az0izB4nYIHej7aiec35wqyHdb71ssAD5yHm...         540
# 4   /40470832_8JS8r4wwSPHFEIT1zrQnB9cEBP7CykzzHPht...         960
# ..                                                ...         ...
# 95  /586212632_-_D9RM1XSADJx1YG-N6_KNKl8UqDysMiQ1K...        1440
# 96  /9174823_OEnBuj3myQrnEwqSYvEnVentGNyGu8v3w_0WO...         720
# 97  /106972738_yvd9vHXilr7eGP7-y2DcSW9GAH620vrMDLP...        1920
# 98  /494681569_7Iurjqy3u17rXUJ55V6pQQVB-uCmNI5hIJ1...        1440
# 99  /58757969_J51FL2CMk5hmuHhgR5wUXroY0nkm-hBqCT-V...        1440
#
#    photo.height photo.visibility  venue.location.neighborhood  \
# 0           650           public                          NaN
# 1           612           public                          NaN
# 2          1440           public                          NaN
# 3           960           public                          NaN
# 4           540           public                          NaN
# ..          ...              ...                          ...
# 95         1920           public                          NaN
# 96          540           public                          NaN
# 97         1440           public                          NaN
# 98         1920           public                          NaN
# 99         1920           public                          NaN
#
#    venue.venuePage.id
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
# ..                ...
# 95                NaN
# 96                NaN
# 97                NaN
# 98                NaN
# 99                NaN
#
# [100 rows x 30 columns]

# %%
resta=[]
oth=[]
for lat,long in zip(nearby_venues['venue.location.lat'],nearby_venues['venue.location.lng']):
    url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
      CLIENT_ID,
      CLIENT_SECRET,
      VERSION,
      lat,long,
      1000,
      100)
    res = requests.get(url).json()
    venue = res['response']['groups'][0]['items']
    nearby_venue = json_normalize(venue)
    df=nearby_venue['venue.categories']

    g=[]
    for i in range(0,df.size):
      g.append(df[i][0]['icon']['prefix'].find('food'))
    co=0
    for i in g:
      if i>1:
        co+=1
    resta.append(co)
    oth.append(len(g)-co)

nearby_venues['restaurant']=resta
nearby_venues['others']=oth
nearby_venues
# Out:
#                          referralId  reasons.count  \
# 0    e-0-4bac7d4df964a5205df73ae3-0              0
# 1    e-0-4e1b27cbd22ddd4af9ea6366-1              0
# 2    e-0-4c68e4238d22c928e6f2b545-2              0
# 3    e-0-4c1f7229b306c928046b68b7-3              0
# 4    e-0-4df9c65c62e1e9a24367f9e5-4              0
# ..                              ...            ...
# 95  e-0-5bdd97f61a2925002549b87c-95              0
# 96  e-0-4e58e6beae6099fc00bf8058-96              0
# 97  e-0-4e3574e362e17d290833ba27-97              0
# 98  e-0-4e4514281495455b10d4ec60-98              0
# 99  e-0-4ea961860aaff9d3d576a354-99              0
#
#                                         reasons.items  \
# 0   [{'summary': 'This spot is popular', 'type': '...
# 1   [{'summary': 'This spot is popular', 'type': '...
# 2   [{'summary': 'This spot is popular', 'type': '...
# 3   [{'summary': 'This spot is popular', 'type': '...
# 4   [{'summary': 'This spot is popular', 'type': '...
# ..                                                ...
# 95  [{'summary': 'This spot is popular', 'type': '...
# 96  [{'summary': 'This spot is popular', 'type': '...
# 97  [{'summary': 'This spot is popular', 'type': '...
# 98  [{'summary': 'This spot is popular', 'type': '...
# 99  [{'summary': 'This spot is popular', 'type': '...
#
#                     venue.id           venue.name  \
# 0   4bac7d4df964a5205df73ae3    10 Downing Street
# 1   4e1b27cbd22ddd4af9ea6366         ITC Kakatiya
# 2   4c68e4238d22c928e6f2b545    Secunderabad Club
# 3   4c1f7229b306c928046b68b7  Fifth Avenue Bakers
# 4   4df9c65c62e1e9a24367f9e5      King & Cardinal
# ..                       ...                  ...
# 95  5bdd97f61a2925002549b87c  Sarath City Capital
# 96  4e58e6beae6099fc00bf8058     Ramoji Film City
# 97  4e3574e362e17d290833ba27        Bhel Township
# 98  4e4514281495455b10d4ec60         Sitara Hotel
# 99  4ea961860aaff9d3d576a354              Masqati
#
#                           venue.location.address  \
# 0   Ground Floor, Lifestyle Building, Greenlands
# 1                           6 -3 -1187, Begumpet
# 2                                         Picket
# 3                                     Sainikpuri
# 4                                   Himayatnagar
# ..                                           ...
# 95                                           NaN
# 96                                           NaN
# 97                                           NaN
# 98                              Ramoji Film City
# 99                                           NaN
#
#            venue.location.crossStreet  venue.location.lat  venue.location.lng  \
# 0                         Begumpet Rd           17.435868           78.457443
# 1                            Begumpet           17.432514           78.457353
# 2                                 NaN           17.452548           78.497400
# 3                                 NaN           17.487673           78.542793
# 4   Narayanguda-himayat Nagar X Roads           17.400678           78.488575
# ..                                ...                 ...                 ...
# 95                                NaN           17.457404           78.363858
# 96                                NaN           17.309839           78.681879
# 97                                NaN           17.495007           78.303459
# 98                                NaN           17.260212           78.678729
# 99                                NaN           17.282320           78.587299
#
#                         venue.location.labeledLatLngs  ...  photo.createdAt  \
# 0   [{'label': 'display', 'lat': 17.43586817493973...  ...       1385400526
# 1   [{'label': 'display', 'lat': 17.43251403198251...  ...       1345966799
# 2   [{'label': 'display', 'lat': 17.45254801837352...  ...       1641567424
# 3   [{'label': 'display', 'lat': 17.48767334633119...  ...       1410359324
# 4   [{'label': 'display', 'lat': 17.40067830505242...  ...       1361023315
# ..                                                ...  ...              ...
# 95  [{'label': 'display', 'lat': 17.45740392880384...  ...       1746864467
# 96  [{'label': 'display', 'lat': 17.30983890015597...  ...       1352697666
# 97  [{'label': 'display', 'lat': 17.49500710963131...  ...       1419483147
# 98  [{'label': 'display', 'lat': 17.26021217265053...  ...       1646413126
# 99  [{'label': 'display', 'lat': 17.28231990270884...  ...       1447075617
#
#                             photo.prefix  \
# 0   https://fastly.4sqi.net/img/general/
# 1   https://fastly.4sqi.net/img/general/
# 2   https://fastly.4sqi.net/img/general/
# 3   https://fastly.4sqi.net/img/general/
# 4   https://fastly.4sqi.net/img/general/
# ..                                   ...
# 95  https://fastly.4sqi.net/img/general/
# 96  https://fastly.4sqi.net/img/general/
# 97  https://fastly.4sqi.net/img/general/
# 98  https://fastly.4sqi.net/img/general/
# 99  https://fastly.4sqi.net/img/general/
#
#                                          photo.suffix photo.width  \
# 0   /32609040_X0yOzEI5oGptuXM0aoHecUKM9ssqdHLfHNHF...         970
# 1    /jIxkFJ4NX8zo6es-KAJUljhtdjADHd8Et-kT5Q8t_oQ.jpg         612
# 2   /36980127_TRsV_zibmCz5rS1m3cHu5qywc8p1w3d19zO-...        1920
# 3   /58807053_Az0izB4nYIHej7aiec35wqyHdb71ssAD5yHm...         540
# 4   /40470832_8JS8r4wwSPHFEIT1zrQnB9cEBP7CykzzHPht...         960
# ..                                                ...         ...
# 95  /586212632_-_D9RM1XSADJx1YG-N6_KNKl8UqDysMiQ1K...        1440
# 96  /9174823_OEnBuj3myQrnEwqSYvEnVentGNyGu8v3w_0WO...         720
# 97  /106972738_yvd9vHXilr7eGP7-y2DcSW9GAH620vrMDLP...        1920
# 98  /494681569_7Iurjqy3u17rXUJ55V6pQQVB-uCmNI5hIJ1...        1440
# 99  /58757969_J51FL2CMk5hmuHhgR5wUXroY0nkm-hBqCT-V...        1440
#
#    photo.height photo.visibility venue.location.neighborhood  \
# 0           650           public                         NaN
# 1           612           public                         NaN
# 2          1440           public                         NaN
# 3           960           public                         NaN
# 4           540           public                         NaN
# ..          ...              ...                         ...
# 95         1920           public                         NaN
# 96          540           public                         NaN
# 97         1440           public                         NaN
# 98         1920           public                         NaN
# 99         1920           public                         NaN
#
#    venue.venuePage.id  restaurant others
# 0                 NaN          27     18
# 1                 NaN          40     29
# 2                 NaN           9      6
# 3                 NaN           4      1
# 4                 NaN          23      9
# ..                ...         ...    ...
# 95                NaN          34     18
# 96                NaN           2      1
# 97                NaN           3      2
# 98                NaN           1      4
# 99                NaN           1      1
#
# [100 rows x 32 columns]

# %%
lat=nearby_venues['venue.location.lat']
long=nearby_venues['venue.location.lng']

# %%
pip install minisom
# Out:
# Requirement already satisfied: minisom in c:\users\admin\anaconda3\lib\site-packages (2.3.5)Note: you may need to restart the kernel to use updated packages.

# %%
f=['venue.location.lat','venue.location.lng']
X = nearby_venues[f]
max_k = 10
## iterations
distortions = []
for i in range(1, max_k+1):
    if len(X) >= i:
       model = cluster.KMeans(n_clusters=i, init='k-means++', max_iter=300, n_init=10, random_state=0)
       model.fit(X)
       distortions.append(model.inertia_)
## best k: the lowest derivative
k = [i*100 for i in np.diff(distortions,2)].index(min([i*100 for i
     in np.diff(distortions,2)]))
## plot
fig, ax = plt.subplots()
ax.plot(range(1, len(distortions)+1), distortions)
ax.axvline(k, ls='--', color="red", label="k = "+str(k))
ax.set(title='The Elbow Method', xlabel='Number of clusters',
       ylabel="Distortion")
ax.legend()
ax.grid(True)
plt.show()
# Out:
# C:\Users\Admin\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1419: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\Admin\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1419: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\Admin\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1419: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\Admin\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1419: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\Admin\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1419: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\Admin\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1419: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\Admin\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1419: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\Admin\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1419: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\Admin\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1419: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\Admin\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1419: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %%
city = "Hyderabad"
## get location
locator = geopy.geocoders.Nominatim(user_agent="MyCoder")
location = locator.geocode(city)
print(location)
## keep latitude and longitude only
location = [location.latitude, location.longitude]
print("[lat, long]:", location)
# Out:
# Hyderabad, Bahadurpura mandal, Hyderabad, Telangana, India
# [lat, long]: [17.360589, 78.4740613]

# %%
nearby_venues.head()
# Out:
#                        referralId  reasons.count  \
# 0  e-0-4bac7d4df964a5205df73ae3-0              0
# 1  e-0-4e1b27cbd22ddd4af9ea6366-1              0
# 2  e-0-4c68e4238d22c928e6f2b545-2              0
# 3  e-0-4c1f7229b306c928046b68b7-3              0
# 4  e-0-4df9c65c62e1e9a24367f9e5-4              0
#
#                                        reasons.items  \
# 0  [{'summary': 'This spot is popular', 'type': '...
# 1  [{'summary': 'This spot is popular', 'type': '...
# 2  [{'summary': 'This spot is popular', 'type': '...
# 3  [{'summary': 'This spot is popular', 'type': '...
# 4  [{'summary': 'This spot is popular', 'type': '...
#
#                    venue.id           venue.name  \
# 0  4bac7d4df964a5205df73ae3    10 Downing Street
# 1  4e1b27cbd22ddd4af9ea6366         ITC Kakatiya
# 2  4c68e4238d22c928e6f2b545    Secunderabad Club
# 3  4c1f7229b306c928046b68b7  Fifth Avenue Bakers
# 4  4df9c65c62e1e9a24367f9e5      King & Cardinal
#
#                          venue.location.address  \
# 0  Ground Floor, Lifestyle Building, Greenlands
# 1                          6 -3 -1187, Begumpet
# 2                                        Picket
# 3                                    Sainikpuri
# 4                                  Himayatnagar
#
#           venue.location.crossStreet  venue.location.lat  venue.location.lng  \
# 0                        Begumpet Rd           17.435868           78.457443
# 1                           Begumpet           17.432514           78.457353
# 2                                NaN           17.452548           78.497400
# 3                                NaN           17.487673           78.542793
# 4  Narayanguda-himayat Nagar X Roads           17.400678           78.488575
#
#                        venue.location.labeledLatLngs  ...  photo.createdAt  \
# 0  [{'label': 'display', 'lat': 17.43586817493973...  ...       1385400526
# 1  [{'label': 'display', 'lat': 17.43251403198251...  ...       1345966799
# 2  [{'label': 'display', 'lat': 17.45254801837352...  ...       1641567424
# 3  [{'label': 'display', 'lat': 17.48767334633119...  ...       1410359324
# 4  [{'label': 'display', 'lat': 17.40067830505242...  ...       1361023315
#
#                            photo.prefix  \
# 0  https://fastly.4sqi.net/img/general/
# 1  https://fastly.4sqi.net/img/general/
# 2  https://fastly.4sqi.net/img/general/
# 3  https://fastly.4sqi.net/img/general/
# 4  https://fastly.4sqi.net/img/general/
#
#                                         photo.suffix photo.width photo.height  \
# 0  /32609040_X0yOzEI5oGptuXM0aoHecUKM9ssqdHLfHNHF...         970          650
# 1   /jIxkFJ4NX8zo6es-KAJUljhtdjADHd8Et-kT5Q8t_oQ.jpg         612          612
# 2  /36980127_TRsV_zibmCz5rS1m3cHu5qywc8p1w3d19zO-...        1920         1440
# 3  /58807053_Az0izB4nYIHej7aiec35wqyHdb71ssAD5yHm...         540          960
# 4  /40470832_8JS8r4wwSPHFEIT1zrQnB9cEBP7CykzzHPht...         960          540
#
#   photo.visibility venue.location.neighborhood venue.venuePage.id  restaurant  \
# 0           public                         NaN                NaN          27
# 1           public                         NaN                NaN          40
# 2           public                         NaN                NaN           9
# 3           public                         NaN                NaN           4
# 4           public                         NaN                NaN          23
#
#   others
# 0     18
# 1     29
# 2      6
# 3      1
# 4      9
#
# [5 rows x 32 columns]

# %%
nearby_venues.columns
# Out:
# Index(['referralId', 'reasons.count', 'reasons.items', 'venue.id',
#        'venue.name', 'venue.location.address', 'venue.location.crossStreet',
#        'venue.location.lat', 'venue.location.lng',
#        'venue.location.labeledLatLngs', 'venue.location.distance',
#        'venue.location.postalCode', 'venue.location.cc', 'venue.location.city',
#        'venue.location.state', 'venue.location.country',
#        'venue.location.formattedAddress', 'venue.categories',
#        'venue.photos.count', 'venue.photos.groups', 'venue.createdAt',
#        'photo.id', 'photo.createdAt', 'photo.prefix', 'photo.suffix',
#        'photo.width', 'photo.height', 'photo.visibility',
#        'venue.location.neighborhood', 'venue.venuePage.id', 'restaurant',
#        'others'],
#       dtype='object')

# %%
n=nearby_venues.drop(['referralId', 'reasons.count', 'reasons.items', 'venue.id',
       'venue.name',
       'venue.location.labeledLatLngs', 'venue.location.distance',
       'venue.location.cc',
       'venue.categories', 'venue.photos.count', 'venue.photos.groups',
       'venue.location.crossStreet', 'venue.location.address','venue.location.city',
       'venue.location.state', 'venue.location.crossStreet',
       'venue.location.neighborhood',	'venue.venuePage.id',
       'venue.location.postalCode','venue.location.country'],axis=1)

# %%
n
# Out:
#     venue.location.lat  venue.location.lng  \
# 0            17.435868           78.457443
# 1            17.432514           78.457353
# 2            17.452548           78.497400
# 3            17.487673           78.542793
# 4            17.400678           78.488575
# ..                 ...                 ...
# 95           17.457404           78.363858
# 96           17.309839           78.681879
# 97           17.495007           78.303459
# 98           17.260212           78.678729
# 99           17.282320           78.587299
#
#                       venue.location.formattedAddress  venue.createdAt  \
# 0   [Ground Floor, Lifestyle Building, Greenlands ...       1269595469
# 1   [6 -3 -1187, Begumpet (Begumpet), Hyderabad 50...       1310402507
# 2     [Picket, Secunderabad 500026, Telangana, India]       1281942563
# 3                 [Sainikpuri, Andhra Pradesh, India]       1277129257
# 4   [Himayatnagar (Narayanguda-himayat Nagar X Roa...       1308214876
# ..                                                ...              ...
# 95                      [Hyderabad, Telangana, India]       1541249014
# 96               [Pochampalle, Andhra Pradesh, India]       1314449086
# 97                      [Hyderabad, Telangana, India]       1312126179
# 98    [Ramoji Film City, Hyderabad, Telangana, India]       1313149992
# 99                             [Uttar Pradesh, India]       1319723398
#
#                     photo.id  photo.createdAt  \
# 0   529388ce498ec78f1904dd61       1385400526
# 1   5039d2cfe4b08256fb6f9235       1345966799
# 2   61d854c052dc4a469d721467       1641567424
# 3   5410601c11d2a80070a4d902       1410359324
# 4   511f9153e4b0841ee067e14a       1361023315
# ..                       ...              ...
# 95  681f09539d5f152b1b343810       1746864467
# 96  50a08742e4b0bae036bcc7da       1352697666
# 97  549b980b498e74a0fcbecb57       1419483147
# 98  62224546cead7256f5092b71       1646413126
# 99  56409f21cd10405a38e29c98       1447075617
#
#                             photo.prefix  \
# 0   https://fastly.4sqi.net/img/general/
# 1   https://fastly.4sqi.net/img/general/
# 2   https://fastly.4sqi.net/img/general/
# 3   https://fastly.4sqi.net/img/general/
# 4   https://fastly.4sqi.net/img/general/
# ..                                   ...
# 95  https://fastly.4sqi.net/img/general/
# 96  https://fastly.4sqi.net/img/general/
# 97  https://fastly.4sqi.net/img/general/
# 98  https://fastly.4sqi.net/img/general/
# 99  https://fastly.4sqi.net/img/general/
#
#                                          photo.suffix  photo.width  \
# 0   /32609040_X0yOzEI5oGptuXM0aoHecUKM9ssqdHLfHNHF...          970
# 1    /jIxkFJ4NX8zo6es-KAJUljhtdjADHd8Et-kT5Q8t_oQ.jpg          612
# 2   /36980127_TRsV_zibmCz5rS1m3cHu5qywc8p1w3d19zO-...         1920
# 3   /58807053_Az0izB4nYIHej7aiec35wqyHdb71ssAD5yHm...          540
# 4   /40470832_8JS8r4wwSPHFEIT1zrQnB9cEBP7CykzzHPht...          960
# ..                                                ...          ...
# 95  /586212632_-_D9RM1XSADJx1YG-N6_KNKl8UqDysMiQ1K...         1440
# 96  /9174823_OEnBuj3myQrnEwqSYvEnVentGNyGu8v3w_0WO...          720
# 97  /106972738_yvd9vHXilr7eGP7-y2DcSW9GAH620vrMDLP...         1920
# 98  /494681569_7Iurjqy3u17rXUJ55V6pQQVB-uCmNI5hIJ1...         1440
# 99  /58757969_J51FL2CMk5hmuHhgR5wUXroY0nkm-hBqCT-V...         1440
#
#     photo.height photo.visibility  restaurant  others
# 0            650           public          27      18
# 1            612           public          40      29
# 2           1440           public           9       6
# 3            960           public           4       1
# 4            540           public          23       9
# ..           ...              ...         ...     ...
# 95          1920           public          34      18
# 96           540           public           2       1
# 97          1440           public           3       2
# 98          1920           public           1       4
# 99          1920           public           1       1
#
# [100 rows x 13 columns]

# %%
n=n.dropna()
n = n.rename(columns={'venue.location.lat': 'lat', 'venue.location.lng': 'long'})
n
# Out:
#           lat       long                    venue.location.formattedAddress  \
# 0   17.435868  78.457443  [Ground Floor, Lifestyle Building, Greenlands ...
# 1   17.432514  78.457353  [6 -3 -1187, Begumpet (Begumpet), Hyderabad 50...
# 2   17.452548  78.497400    [Picket, Secunderabad 500026, Telangana, India]
# 3   17.487673  78.542793                [Sainikpuri, Andhra Pradesh, India]
# 4   17.400678  78.488575  [Himayatnagar (Narayanguda-himayat Nagar X Roa...
# ..        ...        ...                                                ...
# 95  17.457404  78.363858                      [Hyderabad, Telangana, India]
# 96  17.309839  78.681879               [Pochampalle, Andhra Pradesh, India]
# 97  17.495007  78.303459                      [Hyderabad, Telangana, India]
# 98  17.260212  78.678729    [Ramoji Film City, Hyderabad, Telangana, India]
# 99  17.282320  78.587299                             [Uttar Pradesh, India]
#
#     venue.createdAt                  photo.id  photo.createdAt  \
# 0        1269595469  529388ce498ec78f1904dd61       1385400526
# 1        1310402507  5039d2cfe4b08256fb6f9235       1345966799
# 2        1281942563  61d854c052dc4a469d721467       1641567424
# 3        1277129257  5410601c11d2a80070a4d902       1410359324
# 4        1308214876  511f9153e4b0841ee067e14a       1361023315
# ..              ...                       ...              ...
# 95       1541249014  681f09539d5f152b1b343810       1746864467
# 96       1314449086  50a08742e4b0bae036bcc7da       1352697666
# 97       1312126179  549b980b498e74a0fcbecb57       1419483147
# 98       1313149992  62224546cead7256f5092b71       1646413126
# 99       1319723398  56409f21cd10405a38e29c98       1447075617
#
#                             photo.prefix  \
# 0   https://fastly.4sqi.net/img/general/
# 1   https://fastly.4sqi.net/img/general/
# 2   https://fastly.4sqi.net/img/general/
# 3   https://fastly.4sqi.net/img/general/
# 4   https://fastly.4sqi.net/img/general/
# ..                                   ...
# 95  https://fastly.4sqi.net/img/general/
# 96  https://fastly.4sqi.net/img/general/
# 97  https://fastly.4sqi.net/img/general/
# 98  https://fastly.4sqi.net/img/general/
# 99  https://fastly.4sqi.net/img/general/
#
#                                          photo.suffix  photo.width  \
# 0   /32609040_X0yOzEI5oGptuXM0aoHecUKM9ssqdHLfHNHF...          970
# 1    /jIxkFJ4NX8zo6es-KAJUljhtdjADHd8Et-kT5Q8t_oQ.jpg          612
# 2   /36980127_TRsV_zibmCz5rS1m3cHu5qywc8p1w3d19zO-...         1920
# 3   /58807053_Az0izB4nYIHej7aiec35wqyHdb71ssAD5yHm...          540
# 4   /40470832_8JS8r4wwSPHFEIT1zrQnB9cEBP7CykzzHPht...          960
# ..                                                ...          ...
# 95  /586212632_-_D9RM1XSADJx1YG-N6_KNKl8UqDysMiQ1K...         1440
# 96  /9174823_OEnBuj3myQrnEwqSYvEnVentGNyGu8v3w_0WO...          720
# 97  /106972738_yvd9vHXilr7eGP7-y2DcSW9GAH620vrMDLP...         1920
# 98  /494681569_7Iurjqy3u17rXUJ55V6pQQVB-uCmNI5hIJ1...         1440
# 99  /58757969_J51FL2CMk5hmuHhgR5wUXroY0nkm-hBqCT-V...         1440
#
#     photo.height photo.visibility  restaurant  others
# 0            650           public          27      18
# 1            612           public          40      29
# 2           1440           public           9       6
# 3            960           public           4       1
# 4            540           public          23       9
# ..           ...              ...         ...     ...
# 95          1920           public          34      18
# 96           540           public           2       1
# 97          1440           public           3       2
# 98          1920           public           1       4
# 99          1920           public           1       1
#
# [100 rows x 13 columns]

# %%
n['venue.location.formattedAddress']
# Out:
# 0     [Ground Floor, Lifestyle Building, Greenlands ...
# 1     [6 -3 -1187, Begumpet (Begumpet), Hyderabad 50...
# 2       [Picket, Secunderabad 500026, Telangana, India]
# 3                   [Sainikpuri, Andhra Pradesh, India]
# 4     [Himayatnagar (Narayanguda-himayat Nagar X Roa...
#                             ...
# 95                        [Hyderabad, Telangana, India]
# 96                 [Pochampalle, Andhra Pradesh, India]
# 97                        [Hyderabad, Telangana, India]
# 98      [Ramoji Film City, Hyderabad, Telangana, India]
# 99                               [Uttar Pradesh, India]
# Name: venue.location.formattedAddress, Length: 100, dtype: object

# %%
spec_chars = ["[","]"]
for char in spec_chars:
  n['venue.location.formattedAddress'] = n['venue.location.formattedAddress'].astype(str).str.replace(char, ' ')

# %%
n
# Out:
#           lat       long                    venue.location.formattedAddress  \
# 0   17.435868  78.457443   'Ground Floor, Lifestyle Building, Greenlands...
# 1   17.432514  78.457353   '6 -3 -1187, Begumpet (Begumpet)', 'Hyderabad...
# 2   17.452548  78.497400   'Picket', 'Secunderabad 500026', 'Telangana',...
# 3   17.487673  78.542793           'Sainikpuri', 'Andhra Pradesh', 'India'
# 4   17.400678  78.488575   'Himayatnagar (Narayanguda-himayat Nagar X Ro...
# ..        ...        ...                                                ...
# 95  17.457404  78.363858                 'Hyderabad', 'Telangana', 'India'
# 96  17.309839  78.681879          'Pochampalle', 'Andhra Pradesh', 'India'
# 97  17.495007  78.303459                 'Hyderabad', 'Telangana', 'India'
# 98  17.260212  78.678729   'Ramoji Film City', 'Hyderabad', 'Telangana',...
# 99  17.282320  78.587299                          'Uttar Pradesh', 'India'
#
#     venue.createdAt                  photo.id  photo.createdAt  \
# 0        1269595469  529388ce498ec78f1904dd61       1385400526
# 1        1310402507  5039d2cfe4b08256fb6f9235       1345966799
# 2        1281942563  61d854c052dc4a469d721467       1641567424
# 3        1277129257  5410601c11d2a80070a4d902       1410359324
# 4        1308214876  511f9153e4b0841ee067e14a       1361023315
# ..              ...                       ...              ...
# 95       1541249014  681f09539d5f152b1b343810       1746864467
# 96       1314449086  50a08742e4b0bae036bcc7da       1352697666
# 97       1312126179  549b980b498e74a0fcbecb57       1419483147
# 98       1313149992  62224546cead7256f5092b71       1646413126
# 99       1319723398  56409f21cd10405a38e29c98       1447075617
#
#                             photo.prefix  \
# 0   https://fastly.4sqi.net/img/general/
# 1   https://fastly.4sqi.net/img/general/
# 2   https://fastly.4sqi.net/img/general/
# 3   https://fastly.4sqi.net/img/general/
# 4   https://fastly.4sqi.net/img/general/
# ..                                   ...
# 95  https://fastly.4sqi.net/img/general/
# 96  https://fastly.4sqi.net/img/general/
# 97  https://fastly.4sqi.net/img/general/
# 98  https://fastly.4sqi.net/img/general/
# 99  https://fastly.4sqi.net/img/general/
#
#                                          photo.suffix  photo.width  \
# 0   /32609040_X0yOzEI5oGptuXM0aoHecUKM9ssqdHLfHNHF...          970
# 1    /jIxkFJ4NX8zo6es-KAJUljhtdjADHd8Et-kT5Q8t_oQ.jpg          612
# 2   /36980127_TRsV_zibmCz5rS1m3cHu5qywc8p1w3d19zO-...         1920
# 3   /58807053_Az0izB4nYIHej7aiec35wqyHdb71ssAD5yHm...          540
# 4   /40470832_8JS8r4wwSPHFEIT1zrQnB9cEBP7CykzzHPht...          960
# ..                                                ...          ...
# 95  /586212632_-_D9RM1XSADJx1YG-N6_KNKl8UqDysMiQ1K...         1440
# 96  /9174823_OEnBuj3myQrnEwqSYvEnVentGNyGu8v3w_0WO...          720
# 97  /106972738_yvd9vHXilr7eGP7-y2DcSW9GAH620vrMDLP...         1920
# 98  /494681569_7Iurjqy3u17rXUJ55V6pQQVB-uCmNI5hIJ1...         1440
# 99  /58757969_J51FL2CMk5hmuHhgR5wUXroY0nkm-hBqCT-V...         1440
#
#     photo.height photo.visibility  restaurant  others
# 0            650           public          27      18
# 1            612           public          40      29
# 2           1440           public           9       6
# 3            960           public           4       1
# 4            540           public          23       9
# ..           ...              ...         ...     ...
# 95          1920           public          34      18
# 96           540           public           2       1
# 97          1440           public           3       2
# 98          1920           public           1       4
# 99          1920           public           1       1
#
# [100 rows x 13 columns]

# %%
X = n[["lat","long"]]
max_k = 10
## iterations
distortions = []
for i in range(1, max_k+1):
    if len(X) >= i:
       model = cluster.KMeans(n_clusters=i, init='k-means++', max_iter=300, n_init=10, random_state=0)
       model.fit(X)
       distortions.append(model.inertia_)
## best k: the lowest derivative
k = [i*100 for i in np.diff(distortions,2)].index(min([i*100 for i in np.diff(distortions,2)]))
## plot
fig, ax = plt.subplots()
ax.plot(range(1, len(distortions)+1), distortions)
ax.axvline(k, ls='--', color="red", label="k = "+str(k))
ax.set(title='The Elbow Method', xlabel='Number of clusters',
       ylabel="Distortion")
ax.legend()
ax.grid(True)
plt.show()
# Out:
# C:\Users\Admin\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1419: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\Admin\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1419: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\Admin\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1419: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\Admin\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1419: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\Admin\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1419: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\Admin\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1419: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\Admin\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1419: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\Admin\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1419: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\Admin\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1419: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\Admin\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1419: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %%
k = 6
model = cluster.KMeans(n_clusters=k, init='k-means++')
X = n[["lat","long"]]
## clustering
dtf_X = X.copy()
dtf_X["cluster"] = model.fit_predict(X)
## find real centroids
closest, distances = scipy.cluster.vq.vq(model.cluster_centers_,
                     dtf_X.drop("cluster", axis=1).values)
dtf_X["centroids"] = 0
for i in closest:
    dtf_X["centroids"].iloc[i] = 1
## add clustering info to the original dataset
n[["cluster","centroids"]] = dtf_X[["cluster","centroids"]]
n
# Out:
# C:\Users\Admin\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1419: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\Admin\AppData\Local\Temp\ipykernel_4004\1668868172.py:12: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   dtf_X["centroids"].iloc[i] = 1
# C:\Users\Admin\AppData\Local\Temp\ipykernel_4004\1668868172.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dtf_X["centroids"].iloc[i] = 1
# C:\Users\Admin\AppData\Local\Temp\ipykernel_4004\1668868172.py:12: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   dtf_X["centroids"].iloc[i] = 1
# C:\Users\Admin\AppData\Local\Temp\ipykernel_4004\1668868172.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dtf_X["centroids"].iloc[i] = 1
# C:\Users\Admin\AppData\Local\Temp\ipykernel_4004\1668868172.py:12: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   dtf_X["centroids"].iloc[i] = 1
# C:\Users\Admin\AppData\Local\Temp\ipykernel_4004\1668868172.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dtf_X["centroids"].iloc[i] = 1
# C:\Users\Admin\AppData\Local\Temp\ipykernel_4004\1668868172.py:12: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   dtf_X["centroids"].iloc[i] = 1
# C:\Users\Admin\AppData\Local\Temp\ipykernel_4004\1668868172.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dtf_X["centroids"].iloc[i] = 1
# C:\Users\Admin\AppData\Local\Temp\ipykernel_4004\1668868172.py:12: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   dtf_X["centroids"].iloc[i] = 1
# C:\Users\Admin\AppData\Local\Temp\ipykernel_4004\1668868172.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dtf_X["centroids"].iloc[i] = 1
# C:\Users\Admin\AppData\Local\Temp\ipykernel_4004\1668868172.py:12: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   dtf_X["centroids"].iloc[i] = 1
# C:\Users\Admin\AppData\Local\Temp\ipykernel_4004\1668868172.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dtf_X["centroids"].iloc[i] = 1
#           lat       long                    venue.location.formattedAddress  \
# 0   17.435868  78.457443   'Ground Floor, Lifestyle Building, Greenlands...
# 1   17.432514  78.457353   '6 -3 -1187, Begumpet (Begumpet)', 'Hyderabad...
# 2   17.452548  78.497400   'Picket', 'Secunderabad 500026', 'Telangana',...
# 3   17.487673  78.542793           'Sainikpuri', 'Andhra Pradesh', 'India'
# 4   17.400678  78.488575   'Himayatnagar (Narayanguda-himayat Nagar X Ro...
# ..        ...        ...                                                ...
# 95  17.457404  78.363858                 'Hyderabad', 'Telangana', 'India'
# 96  17.309839  78.681879          'Pochampalle', 'Andhra Pradesh', 'India'
# 97  17.495007  78.303459                 'Hyderabad', 'Telangana', 'India'
# 98  17.260212  78.678729   'Ramoji Film City', 'Hyderabad', 'Telangana',...
# 99  17.282320  78.587299                          'Uttar Pradesh', 'India'
#
#     venue.createdAt                  photo.id  photo.createdAt  \
# 0        1269595469  529388ce498ec78f1904dd61       1385400526
# 1        1310402507  5039d2cfe4b08256fb6f9235       1345966799
# 2        1281942563  61d854c052dc4a469d721467       1641567424
# 3        1277129257  5410601c11d2a80070a4d902       1410359324
# 4        1308214876  511f9153e4b0841ee067e14a       1361023315
# ..              ...                       ...              ...
# 95       1541249014  681f09539d5f152b1b343810       1746864467
# 96       1314449086  50a08742e4b0bae036bcc7da       1352697666
# 97       1312126179  549b980b498e74a0fcbecb57       1419483147
# 98       1313149992  62224546cead7256f5092b71       1646413126
# 99       1319723398  56409f21cd10405a38e29c98       1447075617
#
#                             photo.prefix  \
# 0   https://fastly.4sqi.net/img/general/
# 1   https://fastly.4sqi.net/img/general/
# 2   https://fastly.4sqi.net/img/general/
# 3   https://fastly.4sqi.net/img/general/
# 4   https://fastly.4sqi.net/img/general/
# ..                                   ...
# 95  https://fastly.4sqi.net/img/general/
# 96  https://fastly.4sqi.net/img/general/
# 97  https://fastly.4sqi.net/img/general/
# 98  https://fastly.4sqi.net/img/general/
# 99  https://fastly.4sqi.net/img/general/
#
#                                          photo.suffix  photo.width  \
# 0   /32609040_X0yOzEI5oGptuXM0aoHecUKM9ssqdHLfHNHF...          970
# 1    /jIxkFJ4NX8zo6es-KAJUljhtdjADHd8Et-kT5Q8t_oQ.jpg          612
# 2   /36980127_TRsV_zibmCz5rS1m3cHu5qywc8p1w3d19zO-...         1920
# 3   /58807053_Az0izB4nYIHej7aiec35wqyHdb71ssAD5yHm...          540
# 4   /40470832_8JS8r4wwSPHFEIT1zrQnB9cEBP7CykzzHPht...          960
# ..                                                ...          ...
# 95  /586212632_-_D9RM1XSADJx1YG-N6_KNKl8UqDysMiQ1K...         1440
# 96  /9174823_OEnBuj3myQrnEwqSYvEnVentGNyGu8v3w_0WO...          720
# 97  /106972738_yvd9vHXilr7eGP7-y2DcSW9GAH620vrMDLP...         1920
# 98  /494681569_7Iurjqy3u17rXUJ55V6pQQVB-uCmNI5hIJ1...         1440
# 99  /58757969_J51FL2CMk5hmuHhgR5wUXroY0nkm-hBqCT-V...         1440
#
#     photo.height photo.visibility  restaurant  others  cluster  centroids
# 0            650           public          27      18        4          0
# 1            612           public          40      29        4          0
# 2           1440           public           9       6        3          0
# 3            960           public           4       1        3          1
# 4            540           public          23       9        4          0
# ..           ...              ...         ...     ...      ...        ...
# 95          1920           public          34      18        5          0
# 96           540           public           2       1        2          0
# 97          1440           public           3       2        5          0
# 98          1920           public           1       4        2          1
# 99          1920           public           1       1        2          0
#
# [100 rows x 15 columns]

# %%
## plot
fig, ax = plt.subplots()
sns.scatterplot(x="lat", y="long", data=n,
                palette=sns.color_palette("bright",k),
                hue='cluster', size="centroids", size_order=[1,0],
                legend="brief", ax=ax).set_title('Clustering (k='+str(k)+')')
th_centroids = model.cluster_centers_
ax.scatter(th_centroids[:,0], th_centroids[:,1], s=50, c='black',
           marker="x")

# %%
model = cluster.AffinityPropagation()

# %%
k = n["cluster"].nunique()
sns.scatterplot(x="lat", y="long", data=n,
                palette=sns.color_palette("bright",k),
                hue='cluster', size="centroids", size_order=[1,0],
                legend="brief").set_title('Clustering (k='+str(k)+')')
# Out:
# Text(0.5, 1.0, 'Clustering (k=6)')

# %%
x, y = "lat", "long"
color = "cluster"
size = "restaurant"
popup = "venue.location.formattedAddress"
marker = "centroids"
data = n.copy()
## create color column
lst_elements = sorted(list(n[color].unique()))
lst_colors = ['#%06X' % np.random.randint(0, 0xFFFFFF) for i in
              range(len(lst_elements))]
data["color"] = data[color].apply(lambda x:
                lst_colors[lst_elements.index(x)])
## create size column (scaled)
scaler = preprocessing.MinMaxScaler(feature_range=(3,15))
data["size"] = scaler.fit_transform(
               data[size].values.reshape(-1,1)).reshape(-1)
## initialize the map with the starting location
map_ = folium.Map(location=location, tiles="cartodbpositron",
                  zoom_start=11)
## add points
data.apply(lambda row: folium.CircleMarker(
           location=[row[x],row[y]],
           color=row["color"], fill=True,popup=row[popup],
           radius=row["size"]).add_to(map_), axis=1)
## add html legend
legend_html = """<div style="position:fixed; bottom:10px; left:10px; border:2px solid black; z-index:9999; font-size:14px;">&nbsp;<b>"""+color+""":</b><br>"""
for i in lst_elements:
     legend_html = legend_html+"""&nbsp;<i class="fa fa-circle
     fa-1x" style="color:"""+lst_colors[lst_elements.index(i)]+"""">
     </i>&nbsp;"""+str(i)+"""<br>"""
legend_html = legend_html+"""</div>"""
map_.get_root().html.add_child(folium.Element(legend_html))
## add centroids marker
lst_elements = sorted(list(n[marker].unique()))
data[data[marker]==1].apply(lambda row:
           folium.Marker(location=[row[x],row[y]],
           draggable=False,  popup=row[popup] ,
           icon=folium.Icon(color="black")).add_to(map_), axis=1)
## plot the map
map_
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_69053d297191d69e4adc2eabdc7a378f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#     &lt;div style=&quot;position:fixed; bottom:10px; left:10px; border:2px solid black; z-index:9999; font-size:14px;&quot;&gt;&amp;nbsp;&lt;b&gt;cluster:&lt;/b&gt;&lt;br&gt;&amp;nbsp;&lt;i class=&quot;fa fa-circle
#      fa-1x&quot; style=&quot;color:#D760A5&quot;&gt;
#      &lt;/i&gt;&amp;nbsp;0&lt;br&gt;&amp;nbsp;&lt;i class=&quot;fa fa-circle
#      fa-1x&quot; style=&quot;color:#FADBBE&quot;&gt;
#      &lt;/i&gt;&amp;nbsp;1&lt;br&gt;&amp;nbsp;&lt;i class=&quot;fa fa-circle
#      fa-1x&quot; style=&quot;color:#B1870E&quot;&gt;
#      &lt;/i&gt;&amp;nbsp;2&lt;br&gt;&amp;nbsp;&lt;i class=&quot;fa fa-circle
#      fa-1x&quot; style=&quot;color:#3715CE&quot;&gt;
#      &lt;/i&gt;&amp;nbsp;3&lt;br&gt;&amp;nbsp;&lt;i class=&quot;fa fa-circle
#      fa-1x&quot; style=&quot;color:#A181A7&quot;&gt;
#      &lt;/i&gt;&amp;nbsp;4&lt;br&gt;&amp;nbsp;&lt;i class=&quot;fa fa-circle
#      fa-1x&quot; style=&quot;color:#CD2998&quot;&gt;
#      &lt;/i&gt;&amp;nbsp;5&lt;br&gt;&lt;/div&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_69053d297191d69e4adc2eabdc7a378f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_69053d297191d69e4adc2eabdc7a378f = L.map(
#                 &quot;map_69053d297191d69e4adc2eabdc7a378f&quot;,
#                 {
#                     center: [17.360589, 78.4740613],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 11,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b0e93ccf25ef337497ffdb03d1e2b953 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_b0e93ccf25ef337497ffdb03d1e2b953.addTo(map_69053d297191d69e4adc2eabdc7a378f);
#
#
#             var circle_marker_63dcc239644d535c69100660c26cc6bf = L.circleMarker(
#                 [17.43586817493973, 78.45744348829194],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#A181A7&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#A181A7&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 6.9, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_69053d297191d69e4adc2eabdc7a378f);
#
#
#         var popup_2890d0bb6007ca0915b9a3e953683e69 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a0f699255b2723837349dbd701474441 = $(`&lt;div id=&quot;html_a0f699255b2723837349dbd701474441&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt; &#x27;Ground Floor, Lifestyle Building, Greenlands (Begumpet Rd)&#x27;, &#x27;Hyderabad 500016&#x27;, &#x27;Telangana&#x27;, &#x27;India&#x27; &lt;/div&gt;`)[0];
#                 popup_2890d0bb6007ca0915b9a3e953683e69.setContent(html_a0f699255b2723837349dbd701474441);
#
#
#
#         circle_marker_63dcc239644d535c69100660c26cc6bf.bindPopup(popup_2890d0bb6007ca0915b9a3e953683e69)
#         ;
#
#
#
#
#             var circle_marker_b0d46e78794628f68ec94692bc353c39 = L.circleMarker(
#                 [17.432514031982514, 78.45735255628313],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#A181A7&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#A181A7&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 8.85, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_69053d297191d69e4adc2eabdc7a378f);
#
#
#         var popup_812cfe4db8c714c55a7f7d2d4f742659 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_36d7e94346252a9f738ea4c651ffe731 = $(`&lt;div id=&quot;html_36d7e94346252a9f738ea4c651ffe731&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt; &#x27;6 -3 -1187, Begumpet (Begumpet)&#x27;, &#x27;Hyderabad 500016&#x27;, &#x27;Telangana&#x27;, &#x27;India&#x27; &lt;/div&gt;`)[0];
#                 popup_812cfe4db8c714c55a7f7d2d4f742659.setContent(html_36d7e94346252a9f738ea4c651ffe731);
#
#
#
#         circle_marker_b0d46e78794628f68ec94692bc353c39.bindPopup(popup_812cfe4db8c714c55a7f7d2d4f742659)
#         ;
